# %% [markdown]
# This script recorded my pipeline to create the study 'mouse_VISp_L5_128ch'.

# %%
from utils import *
from simulate.simulate import *
from compare.compare import *

import numpy as np
import pickle as pkl
import shutil

import MEArec as mr
import MEAutility as mu

# %% [markdown]
# First retrieve Allen cell models in `cell_models` folder. These models were unzipped and manually categorized into 3 subfolders: `aspiny`, `sparsely_spiny`, `spiny`.

# %% [markdown]
# Then create a new study.

# %%
study_name = 'mouse_VISp_L5_128ch'
study_dir = './studies'
study_path = create_empty_study(study_name,study_dir)

# %% [markdown]
# Then generate templates. Set up the params for generating templates.

# %%
# get default
template_params = mr.get_default_templates_params()

############### Intracellular simulation settings

template_params['sim_time'] = 1 # float, intracellular simulation time (sec)
template_params['target_spikes'] = [3,50] # int, min-max number of spikes in sim_time
template_params['cut_out'] = [2,5] # float, pre/post peak cut_out (msec)
template_params['dt'] = 0.03125 # float, time step (msec), default in 32 kHz
template_params['delay'] = 10 # float, simulation delay (msec)
template_params['weights'] = [0.25,1.75] # float, weights to multiply stimulus amp when spikes number above/below targets

############### Extracellular simulation settings

template_params['rot'] = '3drot' # cell model rotation, ['norot','xrot','yrot','zrot','physrot','3drot']
print(mu.return_mea_list())
template_params['probe'] = 'Neuropixels2-128' # probe, can customize
template_params['ncontacts'] = 10 # int, number of contacts per recording site
template_params['overhang'] = 30 # float, extension (um) beyond MEA boundraies for neuron location, when null limits
template_params['xlim'] = [10,80] # float, limits in x-axis
template_params['ylim'] = None # float, limits in y-axis
template_params['zlim'] = None # float, limits in z-axis
template_params['min_amp'] = 30 # float, min template amplitude
template_params['n'] = 10 # int, number of spike per cell model
template_params['n_overlap_pairs'] = None # number of spatial overlapping templates
template_params['seed'] = 0 # random seed for positions and rotations

#### drifting
template_params['drifting'] = True # bool, turn on drifting simulation
template_params['max_drift'] = 100 # float, max distance for drifting
template_params['min_drift'] = 30 # float, min distance for drifting
template_params['drift_steps'] = 30 # int, number of drift steps
template_params['drift_xlim'] = [-10,10] # float, limits for drift in x-axis
template_params['drift_ylim'] = [-10,10] # float, limits for drift in y-axis
template_params['drift_zlim'] = [20,80] # float, limits for drift in z-axis

#####################################
# Out:
# ['Neuronexus-32', 'Neuropixels-128', 'Neuropixels-24', 'Neuropixels-384', 'Neuropixels-64', 'Neuropixels2-128', 'Neuropixels2-24', 'Neuropixels2-384', 'Neuropixels2-64', 'Neuroseeker-128', 'SqMEA-10-15', 'SqMEA-15-10', 'SqMEA-5-30', 'SqMEA-6-25', 'SqMEA-7-20', 'monotrode', 'tetrode', 'tetrode-mea-d', 'tetrode-mea-l', 'tetrode-mea-s']

# %% [markdown]
# Generate templates.

# %% [markdown]
# Copy probe files from `MEAutility.electrodes`

# %%
template_path = create_empty_templates(study_path,'template_drift')

cell_model_path = Path('./cell_models/mouse_VISp_L5/')
cell_sim_model_path = study_path / 'cell_sim_model'
template_path = template_path

# save template_params
with open((template_path / 'template_params.pkl').as_posix(), 'wb') as f:
    pkl.dump(template_params,f)

generate_template(template_params,cell_model_path,cell_sim_model_path,template_path)
# Out:
# {'beta_distr_params': [1.5, 5],
#  'check_for_drift_amp': False,
#  'cut_out': [2, 5],
#  'delay': 10,
#  'drift_steps': 30,
#  'drift_within_bounds': False,
#  'drift_xlim': [-10, 10],
#  'drift_ylim': [-10, 10],
#  'drift_zlim': [20, 80],
#  'drifting': True,
#  'dt': 0.03125,
#  'max_drift': 100,
#  'max_iterations': 1000,
#  'min_amp': 30,
#  'min_drift': 30,
#  'n': 10,
#  'n_overlap_pairs': None,
#  'ncontacts': 10,
#  'offset': 0,
#  'overhang': 30,
#  'probe': 'Neuropixels2-128',
#  'rot': '3drot',
#  'seed': 0,
#  'sim_time': 1,
#  'target_spikes': [3, 50],
#  'timeout': None,
#  'weights': [0.25, 1.75],
#  'x_distr': 'uniform',
#  'xlim': [10, 80],
#  'ylim': None,
#  'zlim': None}
# [WindowsPath('cell_models/mouse_VISp_L5/spiny/neuronal_model_471087975'), WindowsPath('cell_models/mouse_VISp_L5/spiny/neuronal_model_472306460'), WindowsPath('cell_models/mouse_VISp_L5/spiny/neuronal_model_473863510'), WindowsPath('cell_models/mouse_VISp_L5/spiny/neuronal_model_473863578'), WindowsPath('cell_models/mouse_VISp_L5/spiny/neuronal_model_473871773'), WindowsPath('cell_models/mouse_VISp_L5/spiny/neuronal_model_476637796'), WindowsPath('cell_models/mouse_VISp_L5/spiny/neuronal_model_477839642'), WindowsPath('cell_models/mouse_VISp_L5/spiny/neuronal_model_478047588'), WindowsPath('cell_models/mouse_VISp_L5/spiny/neuronal_model_478047618'), WindowsPath('cell_models/mouse_VISp_L5/spiny/neuronal_model_478513443'), WindowsPath('cell_models/mouse_VISp_L5/spiny/neuronal_model_478513445'), WindowsPath('cell_models/mouse_VISp_L5/spiny/neuronal_model_479427516'), WindowsPath('cell_models/mouse_VISp_L5/spiny/neuronal_model_479694721'), WindowsPath('cell_models/mouse_VISp_L5/spiny/neuronal_model_479695152'), WindowsPath('cell_models/mouse_VISp_L5/spiny/neuronal_model_480624051'), WindowsPath('cell_models/mouse_VISp_L5/spiny/neuronal_model_480624126'), WindowsPath('cell_models/mouse_VISp_L5/spiny/neuronal_model_480624414'), WindowsPath('cell_models/mouse_VISp_L5/spiny/neuronal_model_482520370'), WindowsPath('cell_models/mouse_VISp_L5/spiny/neuronal_model_482529696'), WindowsPath('cell_models/mouse_VISp_L5/spiny/neuronal_model_482655070'), WindowsPath('cell_models/mouse_VISp_L5/spiny/neuronal_model_482657528'), WindowsPath('cell_models/mouse_VISp_L5/spiny/neuronal_model_483108490'), WindowsPath('cell_models/mouse_VISp_L5/spiny/neuronal_model_483109057'), WindowsPath('cell_models/mouse_VISp_L5/spiny/neuronal_model_485591806'), WindowsPath('cell_models/mouse_VISp_L5/spiny/neuronal_model_486052412'), WindowsPath('cell_models/mouse_VISp_L5/spiny/neuronal_model_486052435'), WindowsPath('cell_models/mouse_VISp_L5/spiny/neuronal_model_486508702'), WindowsPath('cell_models/mouse_VISp_L5/spiny/neuronal_model_486508758'), WindowsPath('cell_models/mouse_VISp_L5/spiny/neuronal_model_486508789'), WindowsPath('cell_models/mouse_VISp_L5/spiny/neuronal_model_486509010'), WindowsPath('cell_models/mouse_VISp_L5/spiny/neuronal_model_486509232'), WindowsPath('cell_models/mouse_VISp_L5/spiny/neuronal_model_486556597'), WindowsPath('cell_models/mouse_VISp_L5/spiny/neuronal_model_486556714'), WindowsPath('cell_models/mouse_VISp_L5/spiny/neuronal_model_486556811'), WindowsPath('cell_models/mouse_VISp_L5/spiny/neuronal_model_488462820'), WindowsPath('cell_models/mouse_VISp_L5/spiny/neuronal_model_489932472'), WindowsPath('cell_models/mouse_VISp_L5/spiny/neuronal_model_489932597'), WindowsPath('cell_models/mouse_VISp_L5/spiny/neuronal_model_489932682'), WindowsPath('cell_models/mouse_VISp_L5/spiny/neuronal_model_491517388')]
# [WindowsPath('cell_models/mouse_VISp_L5/sparsely_spiny/neuronal_model_473835796'), WindowsPath('cell_models/mouse_VISp_L5/sparsely_spiny/neuronal_model_477510918')]
# [WindowsPath('cell_models/mouse_VISp_L5/aspiny/neuronal_model_471085845'), WindowsPath('cell_models/mouse_VISp_L5/aspiny/neuronal_model_472299363'), WindowsPath('cell_models/mouse_VISp_L5/aspiny/neuronal_model_472447460'), WindowsPath('cell_models/mouse_VISp_L5/aspiny/neuronal_model_472912177'), WindowsPath('cell_models/mouse_VISp_L5/aspiny/neuronal_model_473465774'), WindowsPath('cell_models/mouse_VISp_L5/aspiny/neuronal_model_476637723'), WindowsPath('cell_models/mouse_VISp_L5/aspiny/neuronal_model_478043748'), WindowsPath('cell_models/mouse_VISp_L5/aspiny/neuronal_model_478513407'), WindowsPath('cell_models/mouse_VISp_L5/aspiny/neuronal_model_478513415'), WindowsPath('cell_models/mouse_VISp_L5/aspiny/neuronal_model_478513437'), WindowsPath('cell_models/mouse_VISp_L5/aspiny/neuronal_model_478513451'), WindowsPath('cell_models/mouse_VISp_L5/aspiny/neuronal_model_478513459'), WindowsPath('cell_models/mouse_VISp_L5/aspiny/neuronal_model_478513461'), WindowsPath('cell_models/mouse_VISp_L5/aspiny/neuronal_model_479234506'), WindowsPath('cell_models/mouse_VISp_L5/aspiny/neuronal_model_479234670'), WindowsPath('cell_models/mouse_VISp_L5/aspiny/neuronal_model_480630211'), WindowsPath('cell_models/mouse_VISp_L5/aspiny/neuronal_model_480631048'), WindowsPath('cell_models/mouse_VISp_L5/aspiny/neuronal_model_480631286'), WindowsPath('cell_models/mouse_VISp_L5/aspiny/neuronal_model_483066358'), WindowsPath('cell_models/mouse_VISp_L5/aspiny/neuronal_model_483106906'), WindowsPath('cell_models/mouse_VISp_L5/aspiny/neuronal_model_484620556'), WindowsPath('cell_models/mouse_VISp_L5/aspiny/neuronal_model_484628276'), WindowsPath('cell_models/mouse_VISp_L5/aspiny/neuronal_model_485476031'), WindowsPath('cell_models/mouse_VISp_L5/aspiny/neuronal_model_485513255'), WindowsPath('cell_models/mouse_VISp_L5/aspiny/neuronal_model_485611914'), WindowsPath('cell_models/mouse_VISp_L5/aspiny/neuronal_model_485904766'), WindowsPath('cell_models/mouse_VISp_L5/aspiny/neuronal_model_486144663'), WindowsPath('cell_models/mouse_VISp_L5/aspiny/neuronal_model_487245869'), WindowsPath('cell_models/mouse_VISp_L5/aspiny/neuronal_model_491623973'), WindowsPath('cell_models/mouse_VISp_L5/aspiny/neuronal_model_496930338')]
# Cell cell_models\mouse_VISp_L5\spiny\neuronal_model_471087975 is spiny
# Input weight: 0.25 - Num Spikes: 42
# Extracellular simulation: cell_models\mouse_VISp_L5\spiny\neuronal_model_471087975
# Seed = 0
# Mechanisms already loaded from path: modfiles.  Aborting.
# Cell neuronal_model_471087975 extracellular spikes to be simulated
# Pre-generating 1000000 random positions
# Cell: neuronal_model_471087975 Progress: [1/10]
# Cell: neuronal_model_471087975 Progress: [2/10]
# Cell: neuronal_model_471087975 Progress: [3/10]
# Cell: neuronal_model_471087975 Progress: [4/10]
# Cell: neuronal_model_471087975 Progress: [5/10]
# Cell: neuronal_model_471087975 Progress: [6/10]
# Cell: neuronal_model_471087975 Progress: [7/10]
# Cell: neuronal_model_471087975 Progress: [8/10]
# Cell: neuronal_model_471087975 Progress: [9/10]
# Cell: neuronal_model_471087975 Progress: [10/10]
# Done generating EAPs for neuronal_model_471087975
# Cell cell_models\mouse_VISp_L5\spiny\neuronal_model_472306460 is spiny
# Mechanisms already loaded from path: modfiles.  Aborting.
# Input weight: 0.25 - Num Spikes: 61
# Input weight: 0.0625 - Num Spikes: 6
# Extracellular simulation: cell_models\mouse_VISp_L5\spiny\neuronal_model_472306460
# Seed = 0
# Mechanisms already loaded from path: modfiles.  Aborting.
# Cell neuronal_model_472306460 extracellular spikes to be simulated
# Pre-generating 1000000 random positions
# Cell: neuronal_model_472306460 Progress: [1/10]
# Cell: neuronal_model_472306460 Progress: [2/10]
# Cell: neuronal_model_472306460 Progress: [3/10]
# Cell: neuronal_model_472306460 Progress: [4/10]
# Cell: neuronal_model_472306460 Progress: [5/10]
# Cell: neuronal_model_472306460 Progress: [6/10]
# Cell: neuronal_model_472306460 Progress: [7/10]
# Cell: neuronal_model_472306460 Progress: [8/10]
# Cell: neuronal_model_472306460 Progress: [9/10]
# Cell: neuronal_model_472306460 Progress: [10/10]
# Done generating EAPs for neuronal_model_472306460
# Cell cell_models\mouse_VISp_L5\spiny\neuronal_model_473863510 is spiny
# Mechanisms already loaded from path: modfiles.  Aborting.
# Input weight: 0.25 - Num Spikes: 81
# Input weight: 0.0625 - Num Spikes: 7
# Extracellular simulation: cell_models\mouse_VISp_L5\spiny\neuronal_model_473863510
# Seed = 0
# Mechanisms already loaded from path: modfiles.  Aborting.
# Cell neuronal_model_473863510 extracellular spikes to be simulated
# Pre-generating 1000000 random positions
# Cell: neuronal_model_473863510 Progress: [1/10]
# Cell: neuronal_model_473863510 Progress: [2/10]
# Cell: neuronal_model_473863510 Progress: [3/10]
# Cell: neuronal_model_473863510 Progress: [4/10]
# Cell: neuronal_model_473863510 Progress: [5/10]
# Cell: neuronal_model_473863510 Progress: [6/10]
# Cell: neuronal_model_473863510 Progress: [7/10]
# Cell: neuronal_model_473863510 Progress: [8/10]
# Cell: neuronal_model_473863510 Progress: [9/10]
# Cell: neuronal_model_473863510 Progress: [10/10]
# Done generating EAPs for neuronal_model_473863510
# Cell cell_models\mouse_VISp_L5\spiny\neuronal_model_473863578 is spiny
# Mechanisms already loaded from path: modfiles.  Aborting.
# Input weight: 0.25 - Num Spikes: 52
# Input weight: 0.0625 - Num Spikes: 9
# Extracellular simulation: cell_models\mouse_VISp_L5\spiny\neuronal_model_473863578
# Seed = 0
# Mechanisms already loaded from path: modfiles.  Aborting.
# Cell neuronal_model_473863578 extracellular spikes to be simulated
# Pre-generating 1000000 random positions
# Cell: neuronal_model_473863578 Progress: [1/10]
# Cell: neuronal_model_473863578 Progress: [2/10]
# Cell: neuronal_model_473863578 Progress: [3/10]
# Cell: neuronal_model_473863578 Progress: [4/10]
# Cell: neuronal_model_473863578 Progress: [5/10]
# Cell: neuronal_model_473863578 Progress: [6/10]
# Cell: neuronal_model_473863578 Progress: [7/10]
# Cell: neuronal_model_473863578 Progress: [8/10]
# Cell: neuronal_model_473863578 Progress: [9/10]
# Cell: neuronal_model_473863578 Progress: [10/10]
# Done generating EAPs for neuronal_model_473863578
# Cell cell_models\mouse_VISp_L5\spiny\neuronal_model_473871773 is spiny
# Mechanisms already loaded from path: modfiles.  Aborting.
# One point section Import3d_Section[1] ending at line 5 has been removed
# 	and child Import3d_Section[2] reattached
# 	and child Import3d_Section[33] reattached
# Input weight: 0.25 - Num Spikes: 19
# Extracellular simulation: cell_models\mouse_VISp_L5\spiny\neuronal_model_473871773
# Seed = 0
# Mechanisms already loaded from path: modfiles.  Aborting.
# One point section Import3d_Section[1] ending at line 5 has been removed
# 	and child Import3d_Section[2] reattached
# 	and child Import3d_Section[33] reattached
# Cell neuronal_model_473871773 extracellular spikes to be simulated
# Pre-generating 1000000 random positions
# Cell: neuronal_model_473871773 Progress: [1/10]
# Cell: neuronal_model_473871773 Progress: [2/10]
# Cell: neuronal_model_473871773 Progress: [3/10]
# Cell: neuronal_model_473871773 Progress: [4/10]
# Cell: neuronal_model_473871773 Progress: [5/10]
# Cell: neuronal_model_473871773 Progress: [6/10]
# Cell: neuronal_model_473871773 Progress: [7/10]
# Cell: neuronal_model_473871773 Progress: [8/10]
# Cell: neuronal_model_473871773 Progress: [9/10]
# Cell: neuronal_model_473871773 Progress: [10/10]
# Done generating EAPs for neuronal_model_473871773
# Cell cell_models\mouse_VISp_L5\spiny\neuronal_model_476637796 is spiny
# Mechanisms already loaded from path: modfiles.  Aborting.
# Input weight: 0.25 - Num Spikes: 31
# Extracellular simulation: cell_models\mouse_VISp_L5\spiny\neuronal_model_476637796
# Seed = 0
# Mechanisms already loaded from path: modfiles.  Aborting.
# Cell neuronal_model_476637796 extracellular spikes to be simulated
# Pre-generating 1000000 random positions
# Cell: neuronal_model_476637796 Progress: [1/10]
# Cell: neuronal_model_476637796 Progress: [2/10]
# Cell: neuronal_model_476637796 Progress: [3/10]
# Cell: neuronal_model_476637796 Progress: [4/10]
# Cell: neuronal_model_476637796 Progress: [5/10]
# Cell: neuronal_model_476637796 Progress: [6/10]
# Cell: neuronal_model_476637796 Progress: [7/10]
# Cell: neuronal_model_476637796 Progress: [8/10]
# Cell: neuronal_model_476637796 Progress: [9/10]
# Cell: neuronal_model_476637796 Progress: [10/10]
# Done generating EAPs for neuronal_model_476637796
# Cell cell_models\mouse_VISp_L5\spiny\neuronal_model_477839642 is spiny
# Mechanisms already loaded from path: modfiles.  Aborting.
# Input weight: 0.25 - Num Spikes: 14
# Extracellular simulation: cell_models\mouse_VISp_L5\spiny\neuronal_model_477839642
# Seed = 0
# Mechanisms already loaded from path: modfiles.  Aborting.
# Cell neuronal_model_477839642 extracellular spikes to be simulated
# Pre-generating 1000000 random positions
# Cell: neuronal_model_477839642 Progress: [1/10]
# Cell: neuronal_model_477839642 Progress: [2/10]
# Cell: neuronal_model_477839642 Progress: [3/10]
# Cell: neuronal_model_477839642 Progress: [4/10]
# Cell: neuronal_model_477839642 Progress: [5/10]
# Cell: neuronal_model_477839642 Progress: [6/10]
# Cell: neuronal_model_477839642 Progress: [7/10]
# Cell: neuronal_model_477839642 Progress: [8/10]
# Cell: neuronal_model_477839642 Progress: [9/10]
# Cell: neuronal_model_477839642 Progress: [10/10]
# Done generating EAPs for neuronal_model_477839642
# Cell cell_models\mouse_VISp_L5\spiny\neuronal_model_478047588 is spiny
# Mechanisms already loaded from path: modfiles.  Aborting.
# Input weight: 0.25 - Num Spikes: 20
# Extracellular simulation: cell_models\mouse_VISp_L5\spiny\neuronal_model_478047588
# Seed = 0
# Mechanisms already loaded from path: modfiles.  Aborting.
# Cell neuronal_model_478047588 extracellular spikes to be simulated
# Pre-generating 1000000 random positions
# Cell: neuronal_model_478047588 Progress: [1/10]
# Cell: neuronal_model_478047588 Progress: [2/10]
# Cell: neuronal_model_478047588 Progress: [3/10]
# Cell: neuronal_model_478047588 Progress: [4/10]
# Cell: neuronal_model_478047588 Progress: [5/10]
# Cell: neuronal_model_478047588 Progress: [6/10]
# Cell: neuronal_model_478047588 Progress: [7/10]
# Cell: neuronal_model_478047588 Progress: [8/10]
# Cell: neuronal_model_478047588 Progress: [9/10]
# Cell: neuronal_model_478047588 Progress: [10/10]
# Done generating EAPs for neuronal_model_478047588
# Cell cell_models\mouse_VISp_L5\spiny\neuronal_model_478047618 is spiny
# Mechanisms already loaded from path: modfiles.  Aborting.
# Input weight: 0.25 - Num Spikes: 56
# Input weight: 0.0625 - Num Spikes: 0
# Input weight: 0.109375 - Num Spikes: 11
# Extracellular simulation: cell_models\mouse_VISp_L5\spiny\neuronal_model_478047618
# Seed = 0
# Mechanisms already loaded from path: modfiles.  Aborting.
# Cell neuronal_model_478047618 extracellular spikes to be simulated
# Pre-generating 1000000 random positions
# Cell: neuronal_model_478047618 Progress: [1/10]
# Cell: neuronal_model_478047618 Progress: [2/10]
# Cell: neuronal_model_478047618 Progress: [3/10]
# Cell: neuronal_model_478047618 Progress: [4/10]
# Cell: neuronal_model_478047618 Progress: [5/10]
# Cell: neuronal_model_478047618 Progress: [6/10]
# Cell: neuronal_model_478047618 Progress: [7/10]
# Cell: neuronal_model_478047618 Progress: [8/10]
# Cell: neuronal_model_478047618 Progress: [9/10]
# Cell: neuronal_model_478047618 Progress: [10/10]
# Done generating EAPs for neuronal_model_478047618
# Cell cell_models\mouse_VISp_L5\spiny\neuronal_model_478513443 is spiny
# Mechanisms already loaded from path: modfiles.  Aborting.
# Input weight: 0.25 - Num Spikes: 29
# Extracellular simulation: cell_models\mouse_VISp_L5\spiny\neuronal_model_478513443
# Seed = 0
# Mechanisms already loaded from path: modfiles.  Aborting.
# Cell neuronal_model_478513443 extracellular spikes to be simulated
# Pre-generating 1000000 random positions
# Cell: neuronal_model_478513443 Progress: [1/10]
# Cell: neuronal_model_478513443 Progress: [2/10]
# Cell: neuronal_model_478513443 Progress: [3/10]
# Cell: neuronal_model_478513443 Progress: [4/10]
# Cell: neuronal_model_478513443 Progress: [5/10]
# Cell: neuronal_model_478513443 Progress: [6/10]
# Cell: neuronal_model_478513443 Progress: [7/10]
# Cell: neuronal_model_478513443 Progress: [8/10]
# Cell: neuronal_model_478513443 Progress: [9/10]
# Cell: neuronal_model_478513443 Progress: [10/10]
# Done generating EAPs for neuronal_model_478513443
# Cell cell_models\mouse_VISp_L5\spiny\neuronal_model_478513445 is spiny
# Mechanisms already loaded from path: modfiles.  Aborting.
# Input weight: 0.25 - Num Spikes: 15
# Extracellular simulation: cell_models\mouse_VISp_L5\spiny\neuronal_model_478513445
# Seed = 0
# Mechanisms already loaded from path: modfiles.  Aborting.
# Cell neuronal_model_478513445 extracellular spikes to be simulated
# Pre-generating 1000000 random positions
# Cell: neuronal_model_478513445 Progress: [1/10]
# Cell: neuronal_model_478513445 Progress: [2/10]
# Cell: neuronal_model_478513445 Progress: [3/10]
# Cell: neuronal_model_478513445 Progress: [4/10]
# Cell: neuronal_model_478513445 Progress: [5/10]
# Cell: neuronal_model_478513445 Progress: [6/10]
# Cell: neuronal_model_478513445 Progress: [7/10]
# Cell: neuronal_model_478513445 Progress: [8/10]
# Cell: neuronal_model_478513445 Progress: [9/10]
# Cell: neuronal_model_478513445 Progress: [10/10]
# Done generating EAPs for neuronal_model_478513445
# Cell cell_models\mouse_VISp_L5\spiny\neuronal_model_479427516 is spiny
# Mechanisms already loaded from path: modfiles.  Aborting.
# Input weight: 0.25 - Num Spikes: 16
# Extracellular simulation: cell_models\mouse_VISp_L5\spiny\neuronal_model_479427516
# Seed = 0
# Mechanisms already loaded from path: modfiles.  Aborting.
# Cell neuronal_model_479427516 extracellular spikes to be simulated
# Pre-generating 1000000 random positions
# Cell: neuronal_model_479427516 Progress: [1/10]
# Cell: neuronal_model_479427516 Progress: [2/10]
# Cell: neuronal_model_479427516 Progress: [3/10]
# Cell: neuronal_model_479427516 Progress: [4/10]
# Cell: neuronal_model_479427516 Progress: [5/10]
# Cell: neuronal_model_479427516 Progress: [6/10]
# Cell: neuronal_model_479427516 Progress: [7/10]
# Cell: neuronal_model_479427516 Progress: [8/10]
# Cell: neuronal_model_479427516 Progress: [9/10]
# Cell: neuronal_model_479427516 Progress: [10/10]
# Done generating EAPs for neuronal_model_479427516
# Cell cell_models\mouse_VISp_L5\spiny\neuronal_model_479694721 is spiny
# Mechanisms already loaded from path: modfiles.  Aborting.
# Input weight: 0.25 - Num Spikes: 86
# Input weight: 0.0625 - Num Spikes: 3
# Input weight: 0.109375 - Num Spikes: 4
# Extracellular simulation: cell_models\mouse_VISp_L5\spiny\neuronal_model_479694721
# Seed = 0
# Mechanisms already loaded from path: modfiles.  Aborting.
# Cell neuronal_model_479694721 extracellular spikes to be simulated
# Pre-generating 1000000 random positions
# Cell: neuronal_model_479694721 Progress: [1/10]
# Cell: neuronal_model_479694721 Progress: [2/10]
# Cell: neuronal_model_479694721 Progress: [3/10]
# Cell: neuronal_model_479694721 Progress: [4/10]
# Cell: neuronal_model_479694721 Progress: [5/10]
# Cell: neuronal_model_479694721 Progress: [6/10]
# Cell: neuronal_model_479694721 Progress: [7/10]
# Cell: neuronal_model_479694721 Progress: [8/10]
# Cell: neuronal_model_479694721 Progress: [9/10]
# Cell: neuronal_model_479694721 Progress: [10/10]
# Done generating EAPs for neuronal_model_479694721
# Cell cell_models\mouse_VISp_L5\spiny\neuronal_model_479695152 is spiny
# Mechanisms already loaded from path: modfiles.  Aborting.
# Input weight: 0.25 - Num Spikes: 108
# Input weight: 0.0625 - Num Spikes: 44
# Extracellular simulation: cell_models\mouse_VISp_L5\spiny\neuronal_model_479695152
# Seed = 0
# Mechanisms already loaded from path: modfiles.  Aborting.
# Cell neuronal_model_479695152 extracellular spikes to be simulated
# Pre-generating 1000000 random positions
# Cell: neuronal_model_479695152 Progress: [1/10]
# Cell: neuronal_model_479695152 Progress: [2/10]
# Cell: neuronal_model_479695152 Progress: [3/10]
# Cell: neuronal_model_479695152 Progress: [4/10]
# Cell: neuronal_model_479695152 Progress: [5/10]
# Cell: neuronal_model_479695152 Progress: [6/10]
# Cell: neuronal_model_479695152 Progress: [7/10]
# Cell: neuronal_model_479695152 Progress: [8/10]
# Cell: neuronal_model_479695152 Progress: [9/10]
# Cell: neuronal_model_479695152 Progress: [10/10]
# Done generating EAPs for neuronal_model_479695152
# Cell cell_models\mouse_VISp_L5\spiny\neuronal_model_480624051 is spiny
# Mechanisms already loaded from path: modfiles.  Aborting.
# Input weight: 0.25 - Num Spikes: 58
# Input weight: 0.0625 - Num Spikes: 29
# Extracellular simulation: cell_models\mouse_VISp_L5\spiny\neuronal_model_480624051
# Seed = 0
# Mechanisms already loaded from path: modfiles.  Aborting.
# Cell neuronal_model_480624051 extracellular spikes to be simulated
# Pre-generating 1000000 random positions
# Cell: neuronal_model_480624051 Progress: [1/10]
# Cell: neuronal_model_480624051 Progress: [2/10]
# Cell: neuronal_model_480624051 Progress: [3/10]
# Cell: neuronal_model_480624051 Progress: [4/10]
# Cell: neuronal_model_480624051 Progress: [5/10]
# Cell: neuronal_model_480624051 Progress: [6/10]
# Cell: neuronal_model_480624051 Progress: [7/10]
# Cell: neuronal_model_480624051 Progress: [8/10]
# Cell: neuronal_model_480624051 Progress: [9/10]
# Cell: neuronal_model_480624051 Progress: [10/10]
# Done generating EAPs for neuronal_model_480624051
# Cell cell_models\mouse_VISp_L5\spiny\neuronal_model_480624126 is spiny
# Mechanisms already loaded from path: modfiles.  Aborting.
# Input weight: 0.25 - Num Spikes: 14
# Extracellular simulation: cell_models\mouse_VISp_L5\spiny\neuronal_model_480624126
# Seed = 0
# Mechanisms already loaded from path: modfiles.  Aborting.
# Cell neuronal_model_480624126 extracellular spikes to be simulated
# Pre-generating 1000000 random positions
# Cell: neuronal_model_480624126 Progress: [1/10]
# Cell: neuronal_model_480624126 Progress: [2/10]
# Cell: neuronal_model_480624126 Progress: [3/10]
# Cell: neuronal_model_480624126 Progress: [4/10]
# Cell: neuronal_model_480624126 Progress: [5/10]
# Cell: neuronal_model_480624126 Progress: [6/10]
# Cell: neuronal_model_480624126 Progress: [7/10]
# Cell: neuronal_model_480624126 Progress: [8/10]
# Cell: neuronal_model_480624126 Progress: [9/10]
# Cell: neuronal_model_480624126 Progress: [10/10]
# Done generating EAPs for neuronal_model_480624126
# Cell cell_models\mouse_VISp_L5\spiny\neuronal_model_480624414 is spiny
# Mechanisms already loaded from path: modfiles.  Aborting.
# Input weight: 0.25 - Num Spikes: 59
# Input weight: 0.0625 - Num Spikes: 0
# Input weight: 0.109375 - Num Spikes: 1
# Input weight: 0.19140625 - Num Spikes: 5
# Extracellular simulation: cell_models\mouse_VISp_L5\spiny\neuronal_model_480624414
# Seed = 0
# Mechanisms already loaded from path: modfiles.  Aborting.
# Cell neuronal_model_480624414 extracellular spikes to be simulated
# Pre-generating 1000000 random positions
# Cell: neuronal_model_480624414 Progress: [1/10]
# Cell: neuronal_model_480624414 Progress: [2/10]
# Cell: neuronal_model_480624414 Progress: [3/10]
# Cell: neuronal_model_480624414 Progress: [4/10]
# Cell: neuronal_model_480624414 Progress: [5/10]
# Cell: neuronal_model_480624414 Progress: [6/10]
# Cell: neuronal_model_480624414 Progress: [7/10]
# Cell: neuronal_model_480624414 Progress: [8/10]
# Cell: neuronal_model_480624414 Progress: [9/10]
# Cell: neuronal_model_480624414 Progress: [10/10]
# Done generating EAPs for neuronal_model_480624414
# Cell cell_models\mouse_VISp_L5\spiny\neuronal_model_482520370 is spiny
# Mechanisms already loaded from path: modfiles.  Aborting.
# Input weight: 0.25 - Num Spikes: 28
# Extracellular simulation: cell_models\mouse_VISp_L5\spiny\neuronal_model_482520370
# Seed = 0
# Mechanisms already loaded from path: modfiles.  Aborting.
# Cell neuronal_model_482520370 extracellular spikes to be simulated
# Pre-generating 1000000 random positions
# Cell: neuronal_model_482520370 Progress: [1/10]
# Cell: neuronal_model_482520370 Progress: [2/10]
# Cell: neuronal_model_482520370 Progress: [3/10]
# Cell: neuronal_model_482520370 Progress: [4/10]
# Cell: neuronal_model_482520370 Progress: [5/10]
# Cell: neuronal_model_482520370 Progress: [6/10]
# Cell: neuronal_model_482520370 Progress: [7/10]
# Cell: neuronal_model_482520370 Progress: [8/10]
# Cell: neuronal_model_482520370 Progress: [9/10]
# Cell: neuronal_model_482520370 Progress: [10/10]
# Done generating EAPs for neuronal_model_482520370
# Cell cell_models\mouse_VISp_L5\spiny\neuronal_model_482529696 is spiny
# Mechanisms already loaded from path: modfiles.  Aborting.
# Input weight: 0.25 - Num Spikes: 56
# Input weight: 0.0625 - Num Spikes: 12
# Extracellular simulation: cell_models\mouse_VISp_L5\spiny\neuronal_model_482529696
# Seed = 0
# Mechanisms already loaded from path: modfiles.  Aborting.
# Cell neuronal_model_482529696 extracellular spikes to be simulated
# Pre-generating 1000000 random positions
# Cell: neuronal_model_482529696 Progress: [1/10]
# Cell: neuronal_model_482529696 Progress: [2/10]
# Cell: neuronal_model_482529696 Progress: [3/10]
# Cell: neuronal_model_482529696 Progress: [4/10]
# Cell: neuronal_model_482529696 Progress: [5/10]
# Cell: neuronal_model_482529696 Progress: [6/10]
# Cell: neuronal_model_482529696 Progress: [7/10]
# Cell: neuronal_model_482529696 Progress: [8/10]
# Cell: neuronal_model_482529696 Progress: [9/10]
# Cell: neuronal_model_482529696 Progress: [10/10]
# Done generating EAPs for neuronal_model_482529696
# Cell cell_models\mouse_VISp_L5\spiny\neuronal_model_482655070 is spiny
# Mechanisms already loaded from path: modfiles.  Aborting.
# Input weight: 0.25 - Num Spikes: 35
# Extracellular simulation: cell_models\mouse_VISp_L5\spiny\neuronal_model_482655070
# Seed = 0
# Mechanisms already loaded from path: modfiles.  Aborting.
# Cell neuronal_model_482655070 extracellular spikes to be simulated
# Pre-generating 1000000 random positions
# Cell: neuronal_model_482655070 Progress: [1/10]
# Cell: neuronal_model_482655070 Progress: [2/10]
# Cell: neuronal_model_482655070 Progress: [3/10]
# Cell: neuronal_model_482655070 Progress: [4/10]
# Cell: neuronal_model_482655070 Progress: [5/10]
# Cell: neuronal_model_482655070 Progress: [6/10]
# Cell: neuronal_model_482655070 Progress: [7/10]
# Cell: neuronal_model_482655070 Progress: [8/10]
# Cell: neuronal_model_482655070 Progress: [9/10]
# Cell: neuronal_model_482655070 Progress: [10/10]
# Done generating EAPs for neuronal_model_482655070
# Cell cell_models\mouse_VISp_L5\spiny\neuronal_model_482657528 is spiny
# Mechanisms already loaded from path: modfiles.  Aborting.
# Input weight: 0.25 - Num Spikes: 46
# Extracellular simulation: cell_models\mouse_VISp_L5\spiny\neuronal_model_482657528
# Seed = 0
# Mechanisms already loaded from path: modfiles.  Aborting.
# Cell neuronal_model_482657528 extracellular spikes to be simulated
# Pre-generating 1000000 random positions
# Cell: neuronal_model_482657528 Progress: [1/10]
# Cell: neuronal_model_482657528 Progress: [2/10]
# Cell: neuronal_model_482657528 Progress: [3/10]
# Cell: neuronal_model_482657528 Progress: [4/10]
# Cell: neuronal_model_482657528 Progress: [5/10]
# Cell: neuronal_model_482657528 Progress: [6/10]
# Cell: neuronal_model_482657528 Progress: [7/10]
# Cell: neuronal_model_482657528 Progress: [8/10]
# Cell: neuronal_model_482657528 Progress: [9/10]
# Cell: neuronal_model_482657528 Progress: [10/10]
# Done generating EAPs for neuronal_model_482657528
# Cell cell_models\mouse_VISp_L5\spiny\neuronal_model_483108490 is spiny
# Mechanisms already loaded from path: modfiles.  Aborting.
# Input weight: 0.25 - Num Spikes: 1
# Input weight: 0.4375 - Num Spikes: 1
# Input weight: 0.765625 - Num Spikes: 1
# Input weight: 1.33984375 - Num Spikes: 2
# Input weight: 2.3447265625 - Num Spikes: 1
# Input weight: 4.103271484375 - Num Spikes: 1
# Input weight: 7.18072509765625 - Num Spikes: 1
# Input weight: 12.566268920898438 - Num Spikes: 1
# Input weight: 21.990970611572266 - Num Spikes: 1
# Input weight: 38.484198570251465 - Num Spikes: 1
# Cell cell_models\mouse_VISp_L5\spiny\neuronal_model_483108490 is bad. Excluded..
# Cell cell_models\mouse_VISp_L5\spiny\neuronal_model_483109057 is spiny
# Mechanisms already loaded from path: modfiles.  Aborting.
# Input weight: 0.25 - Num Spikes: 13
# Extracellular simulation: cell_models\mouse_VISp_L5\spiny\neuronal_model_483109057
# Seed = 0
# Mechanisms already loaded from path: modfiles.  Aborting.
# Cell neuronal_model_483109057 extracellular spikes to be simulated
# Pre-generating 1000000 random positions
# Cell: neuronal_model_483109057 Progress: [1/10]
# Cell: neuronal_model_483109057 Progress: [2/10]
# Cell: neuronal_model_483109057 Progress: [3/10]
# Cell: neuronal_model_483109057 Progress: [4/10]
# Cell: neuronal_model_483109057 Progress: [5/10]
# Cell: neuronal_model_483109057 Progress: [6/10]
# Cell: neuronal_model_483109057 Progress: [7/10]
# Cell: neuronal_model_483109057 Progress: [8/10]
# Cell: neuronal_model_483109057 Progress: [9/10]
# Cell: neuronal_model_483109057 Progress: [10/10]
# Done generating EAPs for neuronal_model_483109057
# Cell cell_models\mouse_VISp_L5\spiny\neuronal_model_485591806 is spiny
# Mechanisms already loaded from path: modfiles.  Aborting.
# Input weight: 0.25 - Num Spikes: 29
# Extracellular simulation: cell_models\mouse_VISp_L5\spiny\neuronal_model_485591806
# Seed = 0
# Mechanisms already loaded from path: modfiles.  Aborting.
# Cell neuronal_model_485591806 extracellular spikes to be simulated
# Pre-generating 1000000 random positions
# Cell: neuronal_model_485591806 Progress: [1/10]
# Cell: neuronal_model_485591806 Progress: [2/10]
# Cell: neuronal_model_485591806 Progress: [3/10]
# Cell: neuronal_model_485591806 Progress: [4/10]
# Cell: neuronal_model_485591806 Progress: [5/10]
# Cell: neuronal_model_485591806 Progress: [6/10]
# Cell: neuronal_model_485591806 Progress: [7/10]
# Cell: neuronal_model_485591806 Progress: [8/10]
# Cell: neuronal_model_485591806 Progress: [9/10]
# Cell: neuronal_model_485591806 Progress: [10/10]
# Done generating EAPs for neuronal_model_485591806
# Cell cell_models\mouse_VISp_L5\spiny\neuronal_model_486052412 is spiny
# Mechanisms already loaded from path: modfiles.  Aborting.
# Input weight: 0.25 - Num Spikes: 12
# Extracellular simulation: cell_models\mouse_VISp_L5\spiny\neuronal_model_486052412
# Seed = 0
# Mechanisms already loaded from path: modfiles.  Aborting.
# Cell neuronal_model_486052412 extracellular spikes to be simulated
# Pre-generating 1000000 random positions
# Cell: neuronal_model_486052412 Progress: [1/10]
# Cell: neuronal_model_486052412 Progress: [2/10]
# Cell: neuronal_model_486052412 Progress: [3/10]
# Cell: neuronal_model_486052412 Progress: [4/10]
# Cell: neuronal_model_486052412 Progress: [5/10]
# Cell: neuronal_model_486052412 Progress: [6/10]
# Cell: neuronal_model_486052412 Progress: [7/10]
# Cell: neuronal_model_486052412 Progress: [8/10]
# Cell: neuronal_model_486052412 Progress: [9/10]
# Cell: neuronal_model_486052412 Progress: [10/10]
# Done generating EAPs for neuronal_model_486052412
# Cell cell_models\mouse_VISp_L5\spiny\neuronal_model_486052435 is spiny
# Mechanisms already loaded from path: modfiles.  Aborting.
# Input weight: 0.25 - Num Spikes: 22
# Extracellular simulation: cell_models\mouse_VISp_L5\spiny\neuronal_model_486052435
# Seed = 0
# Mechanisms already loaded from path: modfiles.  Aborting.
# Cell neuronal_model_486052435 extracellular spikes to be simulated
# Pre-generating 1000000 random positions
# Cell: neuronal_model_486052435 Progress: [1/10]
# Cell: neuronal_model_486052435 Progress: [2/10]
# Cell: neuronal_model_486052435 Progress: [3/10]
# Cell: neuronal_model_486052435 Progress: [4/10]
# Cell: neuronal_model_486052435 Progress: [5/10]
# Cell: neuronal_model_486052435 Progress: [6/10]
# Cell: neuronal_model_486052435 Progress: [7/10]
# Cell: neuronal_model_486052435 Progress: [8/10]
# Cell: neuronal_model_486052435 Progress: [9/10]
# Cell: neuronal_model_486052435 Progress: [10/10]
# Done generating EAPs for neuronal_model_486052435
# Cell cell_models\mouse_VISp_L5\spiny\neuronal_model_486508702 is spiny
# Mechanisms already loaded from path: modfiles.  Aborting.
# Input weight: 0.25 - Num Spikes: 84
# Input weight: 0.0625 - Num Spikes: 18
# Extracellular simulation: cell_models\mouse_VISp_L5\spiny\neuronal_model_486508702
# Seed = 0
# Mechanisms already loaded from path: modfiles.  Aborting.
# Cell neuronal_model_486508702 extracellular spikes to be simulated
# Pre-generating 1000000 random positions
# Cell: neuronal_model_486508702 Progress: [1/10]
# Cell: neuronal_model_486508702 Progress: [2/10]
# Cell: neuronal_model_486508702 Progress: [3/10]
# Cell: neuronal_model_486508702 Progress: [4/10]
# Cell: neuronal_model_486508702 Progress: [5/10]
# Cell: neuronal_model_486508702 Progress: [6/10]
# Cell: neuronal_model_486508702 Progress: [7/10]
# Cell: neuronal_model_486508702 Progress: [8/10]
# Cell: neuronal_model_486508702 Progress: [9/10]
# Cell: neuronal_model_486508702 Progress: [10/10]
# Done generating EAPs for neuronal_model_486508702
# Cell cell_models\mouse_VISp_L5\spiny\neuronal_model_486508758 is spiny
# Mechanisms already loaded from path: modfiles.  Aborting.
# Input weight: 0.25 - Num Spikes: 39
# Extracellular simulation: cell_models\mouse_VISp_L5\spiny\neuronal_model_486508758
# Seed = 0
# Mechanisms already loaded from path: modfiles.  Aborting.
# Cell neuronal_model_486508758 extracellular spikes to be simulated
# Pre-generating 1000000 random positions
# Cell: neuronal_model_486508758 Progress: [1/10]
# Cell: neuronal_model_486508758 Progress: [2/10]
# Cell: neuronal_model_486508758 Progress: [3/10]
# Cell: neuronal_model_486508758 Progress: [4/10]
# Cell: neuronal_model_486508758 Progress: [5/10]
# Cell: neuronal_model_486508758 Progress: [6/10]
# Cell: neuronal_model_486508758 Progress: [7/10]
# Cell: neuronal_model_486508758 Progress: [8/10]
# Cell: neuronal_model_486508758 Progress: [9/10]
# Cell: neuronal_model_486508758 Progress: [10/10]
# Done generating EAPs for neuronal_model_486508758
# Cell cell_models\mouse_VISp_L5\spiny\neuronal_model_486508789 is spiny
# Mechanisms already loaded from path: modfiles.  Aborting.
# Input weight: 0.25 - Num Spikes: 38
# Extracellular simulation: cell_models\mouse_VISp_L5\spiny\neuronal_model_486508789
# Seed = 0
# Mechanisms already loaded from path: modfiles.  Aborting.
# Cell neuronal_model_486508789 extracellular spikes to be simulated
# Pre-generating 1000000 random positions
# Cell: neuronal_model_486508789 Progress: [1/10]
# Cell: neuronal_model_486508789 Progress: [2/10]
# Cell: neuronal_model_486508789 Progress: [3/10]
# Cell: neuronal_model_486508789 Progress: [4/10]
# Cell: neuronal_model_486508789 Progress: [5/10]
# Cell: neuronal_model_486508789 Progress: [6/10]
# Cell: neuronal_model_486508789 Progress: [7/10]
# Cell: neuronal_model_486508789 Progress: [8/10]
# Cell: neuronal_model_486508789 Progress: [9/10]
# Cell: neuronal_model_486508789 Progress: [10/10]
# Done generating EAPs for neuronal_model_486508789
# Cell cell_models\mouse_VISp_L5\spiny\neuronal_model_486509010 is spiny
# Mechanisms already loaded from path: modfiles.  Aborting.
# Input weight: 0.25 - Num Spikes: 28
# Extracellular simulation: cell_models\mouse_VISp_L5\spiny\neuronal_model_486509010
# Seed = 0
# Mechanisms already loaded from path: modfiles.  Aborting.
# Cell neuronal_model_486509010 extracellular spikes to be simulated
# Pre-generating 1000000 random positions
# Cell: neuronal_model_486509010 Progress: [1/10]
# Cell: neuronal_model_486509010 Progress: [2/10]
# Cell: neuronal_model_486509010 Progress: [3/10]
# Cell: neuronal_model_486509010 Progress: [4/10]
# Cell: neuronal_model_486509010 Progress: [5/10]
# Cell: neuronal_model_486509010 Progress: [6/10]
# Cell: neuronal_model_486509010 Progress: [7/10]
# Cell: neuronal_model_486509010 Progress: [8/10]
# Cell: neuronal_model_486509010 Progress: [9/10]
# Cell: neuronal_model_486509010 Progress: [10/10]
# Done generating EAPs for neuronal_model_486509010
# Cell cell_models\mouse_VISp_L5\spiny\neuronal_model_486509232 is spiny
# Mechanisms already loaded from path: modfiles.  Aborting.
# Input weight: 0.25 - Num Spikes: 40
# Extracellular simulation: cell_models\mouse_VISp_L5\spiny\neuronal_model_486509232
# Seed = 0
# Mechanisms already loaded from path: modfiles.  Aborting.
# Cell neuronal_model_486509232 extracellular spikes to be simulated
# Pre-generating 1000000 random positions
# Cell: neuronal_model_486509232 Progress: [1/10]
# Cell: neuronal_model_486509232 Progress: [2/10]
# Cell: neuronal_model_486509232 Progress: [3/10]
# Cell: neuronal_model_486509232 Progress: [4/10]
# Cell: neuronal_model_486509232 Progress: [5/10]
# Cell: neuronal_model_486509232 Progress: [6/10]
# Cell: neuronal_model_486509232 Progress: [7/10]
# Cell: neuronal_model_486509232 Progress: [8/10]
# Cell: neuronal_model_486509232 Progress: [9/10]
# Cell: neuronal_model_486509232 Progress: [10/10]
# Done generating EAPs for neuronal_model_486509232
# Cell cell_models\mouse_VISp_L5\spiny\neuronal_model_486556597 is spiny
# Mechanisms already loaded from path: modfiles.  Aborting.
# Input weight: 0.25 - Num Spikes: 114
# Input weight: 0.0625 - Num Spikes: 60
# Input weight: 0.015625 - Num Spikes: 35
# Extracellular simulation: cell_models\mouse_VISp_L5\spiny\neuronal_model_486556597
# Seed = 0
# Mechanisms already loaded from path: modfiles.  Aborting.
# Cell neuronal_model_486556597 extracellular spikes to be simulated
# Pre-generating 1000000 random positions
# Cell: neuronal_model_486556597 Progress: [1/10]
# Cell: neuronal_model_486556597 Progress: [2/10]
# Cell: neuronal_model_486556597 Progress: [3/10]
# Cell: neuronal_model_486556597 Progress: [4/10]
# Cell: neuronal_model_486556597 Progress: [5/10]
# Cell: neuronal_model_486556597 Progress: [6/10]
# Cell: neuronal_model_486556597 Progress: [7/10]
# Cell: neuronal_model_486556597 Progress: [8/10]
# Cell: neuronal_model_486556597 Progress: [9/10]
# Cell: neuronal_model_486556597 Progress: [10/10]
# Done generating EAPs for neuronal_model_486556597
# Cell cell_models\mouse_VISp_L5\spiny\neuronal_model_486556714 is spiny
# Mechanisms already loaded from path: modfiles.  Aborting.
# Input weight: 0.25 - Num Spikes: 36
# Extracellular simulation: cell_models\mouse_VISp_L5\spiny\neuronal_model_486556714
# Seed = 0
# Mechanisms already loaded from path: modfiles.  Aborting.
# Cell neuronal_model_486556714 extracellular spikes to be simulated
# Pre-generating 1000000 random positions
# Cell: neuronal_model_486556714 Progress: [1/10]
# Cell: neuronal_model_486556714 Progress: [2/10]
# Cell: neuronal_model_486556714 Progress: [3/10]
# Cell: neuronal_model_486556714 Progress: [4/10]
# Cell: neuronal_model_486556714 Progress: [5/10]
# Cell: neuronal_model_486556714 Progress: [6/10]
# Cell: neuronal_model_486556714 Progress: [7/10]
# Cell: neuronal_model_486556714 Progress: [8/10]
# Cell: neuronal_model_486556714 Progress: [9/10]
# Cell: neuronal_model_486556714 Progress: [10/10]
# Done generating EAPs for neuronal_model_486556714
# Cell cell_models\mouse_VISp_L5\spiny\neuronal_model_486556811 is spiny
# Mechanisms already loaded from path: modfiles.  Aborting.
# Input weight: 0.25 - Num Spikes: 16
# Extracellular simulation: cell_models\mouse_VISp_L5\spiny\neuronal_model_486556811
# Seed = 0
# Mechanisms already loaded from path: modfiles.  Aborting.
# Cell neuronal_model_486556811 extracellular spikes to be simulated
# Pre-generating 1000000 random positions
# Cell: neuronal_model_486556811 Progress: [1/10]
# Cell: neuronal_model_486556811 Progress: [2/10]
# Cell: neuronal_model_486556811 Progress: [3/10]
# Cell: neuronal_model_486556811 Progress: [4/10]
# Cell: neuronal_model_486556811 Progress: [5/10]
# Cell: neuronal_model_486556811 Progress: [6/10]
# Cell: neuronal_model_486556811 Progress: [7/10]
# Cell: neuronal_model_486556811 Progress: [8/10]
# Cell: neuronal_model_486556811 Progress: [9/10]
# Cell: neuronal_model_486556811 Progress: [10/10]
# Done generating EAPs for neuronal_model_486556811
# Cell cell_models\mouse_VISp_L5\spiny\neuronal_model_488462820 is spiny
# Mechanisms already loaded from path: modfiles.  Aborting.
# Input weight: 0.25 - Num Spikes: 46
# Extracellular simulation: cell_models\mouse_VISp_L5\spiny\neuronal_model_488462820
# Seed = 0
# Mechanisms already loaded from path: modfiles.  Aborting.
# Cell neuronal_model_488462820 extracellular spikes to be simulated
# Pre-generating 1000000 random positions
# Cell: neuronal_model_488462820 Progress: [1/10]
# Cell: neuronal_model_488462820 Progress: [2/10]
# Cell: neuronal_model_488462820 Progress: [3/10]
# Cell: neuronal_model_488462820 Progress: [4/10]
# Cell: neuronal_model_488462820 Progress: [5/10]
# Cell: neuronal_model_488462820 Progress: [6/10]
# Cell: neuronal_model_488462820 Progress: [7/10]
# Cell: neuronal_model_488462820 Progress: [8/10]
# Cell: neuronal_model_488462820 Progress: [9/10]
# Cell: neuronal_model_488462820 Progress: [10/10]
# Done generating EAPs for neuronal_model_488462820
# Cell cell_models\mouse_VISp_L5\spiny\neuronal_model_489932472 is spiny
# Mechanisms already loaded from path: modfiles.  Aborting.
# Input weight: 0.25 - Num Spikes: 38
# Extracellular simulation: cell_models\mouse_VISp_L5\spiny\neuronal_model_489932472
# Seed = 0
# Mechanisms already loaded from path: modfiles.  Aborting.
# Cell neuronal_model_489932472 extracellular spikes to be simulated
# Pre-generating 1000000 random positions
# Cell: neuronal_model_489932472 Progress: [1/10]
# Cell: neuronal_model_489932472 Progress: [2/10]
# Cell: neuronal_model_489932472 Progress: [3/10]
# Cell: neuronal_model_489932472 Progress: [4/10]
# Cell: neuronal_model_489932472 Progress: [5/10]
# Cell: neuronal_model_489932472 Progress: [6/10]
# Cell: neuronal_model_489932472 Progress: [7/10]
# Cell: neuronal_model_489932472 Progress: [8/10]
# Cell: neuronal_model_489932472 Progress: [9/10]
# Cell: neuronal_model_489932472 Progress: [10/10]
# Done generating EAPs for neuronal_model_489932472
# Cell cell_models\mouse_VISp_L5\spiny\neuronal_model_489932597 is spiny
# Mechanisms already loaded from path: modfiles.  Aborting.
# Input weight: 0.25 - Num Spikes: 56
# Input weight: 0.0625 - Num Spikes: 20
# Extracellular simulation: cell_models\mouse_VISp_L5\spiny\neuronal_model_489932597
# Seed = 0
# Mechanisms already loaded from path: modfiles.  Aborting.
# Cell neuronal_model_489932597 extracellular spikes to be simulated
# Pre-generating 1000000 random positions
# Cell: neuronal_model_489932597 Progress: [1/10]
# Cell: neuronal_model_489932597 Progress: [2/10]
# Cell: neuronal_model_489932597 Progress: [3/10]
# Cell: neuronal_model_489932597 Progress: [4/10]
# Cell: neuronal_model_489932597 Progress: [5/10]
# Cell: neuronal_model_489932597 Progress: [6/10]
# Cell: neuronal_model_489932597 Progress: [7/10]
# Cell: neuronal_model_489932597 Progress: [8/10]
# Cell: neuronal_model_489932597 Progress: [9/10]
# Cell: neuronal_model_489932597 Progress: [10/10]
# Done generating EAPs for neuronal_model_489932597
# Cell cell_models\mouse_VISp_L5\spiny\neuronal_model_489932682 is spiny
# Mechanisms already loaded from path: modfiles.  Aborting.
# Input weight: 0.25 - Num Spikes: 13
# Extracellular simulation: cell_models\mouse_VISp_L5\spiny\neuronal_model_489932682
# Seed = 0
# Mechanisms already loaded from path: modfiles.  Aborting.
# Cell neuronal_model_489932682 extracellular spikes to be simulated
# Pre-generating 1000000 random positions
# Cell: neuronal_model_489932682 Progress: [1/10]
# Cell: neuronal_model_489932682 Progress: [2/10]
# Cell: neuronal_model_489932682 Progress: [3/10]
# Cell: neuronal_model_489932682 Progress: [4/10]
# Cell: neuronal_model_489932682 Progress: [5/10]
# Cell: neuronal_model_489932682 Progress: [6/10]
# Cell: neuronal_model_489932682 Progress: [7/10]
# Cell: neuronal_model_489932682 Progress: [8/10]
# Cell: neuronal_model_489932682 Progress: [9/10]
# Cell: neuronal_model_489932682 Progress: [10/10]
# Done generating EAPs for neuronal_model_489932682
# Cell cell_models\mouse_VISp_L5\spiny\neuronal_model_491517388 is spiny
# Mechanisms already loaded from path: modfiles.  Aborting.
# Input weight: 0.25 - Num Spikes: 55
# Input weight: 0.0625 - Num Spikes: 5
# Extracellular simulation: cell_models\mouse_VISp_L5\spiny\neuronal_model_491517388
# Seed = 0
# Mechanisms already loaded from path: modfiles.  Aborting.
# Cell neuronal_model_491517388 extracellular spikes to be simulated
# Pre-generating 1000000 random positions
# Cell: neuronal_model_491517388 Progress: [1/10]
# Cell: neuronal_model_491517388 Progress: [2/10]
# Cell: neuronal_model_491517388 Progress: [3/10]
# Cell: neuronal_model_491517388 Progress: [4/10]
# Cell: neuronal_model_491517388 Progress: [5/10]
# Cell: neuronal_model_491517388 Progress: [6/10]
# Cell: neuronal_model_491517388 Progress: [7/10]
# Cell: neuronal_model_491517388 Progress: [8/10]
# Cell: neuronal_model_491517388 Progress: [9/10]
# Cell: neuronal_model_491517388 Progress: [10/10]
# Done generating EAPs for neuronal_model_491517388
# Cell cell_models\mouse_VISp_L5\sparsely_spiny\neuronal_model_473835796 is sparsely_spiny
# Mechanisms already loaded from path: modfiles.  Aborting.
# Input weight: 0.25 - Num Spikes: 29
# Extracellular simulation: cell_models\mouse_VISp_L5\sparsely_spiny\neuronal_model_473835796
# Seed = 0
# Mechanisms already loaded from path: modfiles.  Aborting.
# Cell neuronal_model_473835796 extracellular spikes to be simulated
# Pre-generating 1000000 random positions
# Cell: neuronal_model_473835796 Progress: [1/10]
# Cell: neuronal_model_473835796 Progress: [2/10]
# Cell: neuronal_model_473835796 Progress: [3/10]
# Cell: neuronal_model_473835796 Progress: [4/10]
# Cell: neuronal_model_473835796 Progress: [5/10]
# Cell: neuronal_model_473835796 Progress: [6/10]
# Cell: neuronal_model_473835796 Progress: [7/10]
# Cell: neuronal_model_473835796 Progress: [8/10]
# Cell: neuronal_model_473835796 Progress: [9/10]
# Cell: neuronal_model_473835796 Progress: [10/10]
# Done generating EAPs for neuronal_model_473835796
# Cell cell_models\mouse_VISp_L5\sparsely_spiny\neuronal_model_477510918 is sparsely_spiny
# Mechanisms already loaded from path: modfiles.  Aborting.
# warning reconstruction.swc: more than one tree:
#   root at line 2
#   root at line 10632
#   root at line 10633
#   root at line 10718
#   root at line 10762
#   root at line 10862
#   root at line 10934
# One point section Import3d_Section[247] ending at line 10632 has been removed
# Input weight: 0.25 - Num Spikes: 26
# Extracellular simulation: cell_models\mouse_VISp_L5\sparsely_spiny\neuronal_model_477510918
# Seed = 0
# Mechanisms already loaded from path: modfiles.  Aborting.
# warning reconstruction.swc: more than one tree:
#   root at line 2
#   root at line 10632
#   root at line 10633
#   root at line 10718
#   root at line 10762
#   root at line 10862
#   root at line 10934
# One point section Import3d_Section[247] ending at line 10632 has been removed
# Cell neuronal_model_477510918 extracellular spikes to be simulated
# Pre-generating 1000000 random positions
# Cell: neuronal_model_477510918 Progress: [1/10]
# Cell: neuronal_model_477510918 Progress: [2/10]
# Cell: neuronal_model_477510918 Progress: [3/10]
# Cell: neuronal_model_477510918 Progress: [4/10]
# Cell: neuronal_model_477510918 Progress: [5/10]
# Cell: neuronal_model_477510918 Progress: [6/10]
# Cell: neuronal_model_477510918 Progress: [7/10]
# Cell: neuronal_model_477510918 Progress: [8/10]
# Cell: neuronal_model_477510918 Progress: [9/10]
# Cell: neuronal_model_477510918 Progress: [10/10]
# Done generating EAPs for neuronal_model_477510918
# Cell cell_models\mouse_VISp_L5\aspiny\neuronal_model_471085845 is aspiny
# Mechanisms already loaded from path: modfiles.  Aborting.
# Input weight: 0.25 - Num Spikes: 84
# Input weight: 0.0625 - Num Spikes: 0
# Input weight: 0.109375 - Num Spikes: 18
# Extracellular simulation: cell_models\mouse_VISp_L5\aspiny\neuronal_model_471085845
# Seed = 0
# Mechanisms already loaded from path: modfiles.  Aborting.
# Cell neuronal_model_471085845 extracellular spikes to be simulated
# Pre-generating 1000000 random positions
# Cell: neuronal_model_471085845 Progress: [1/10]
# Cell: neuronal_model_471085845 Progress: [2/10]
# Cell: neuronal_model_471085845 Progress: [3/10]
# Cell: neuronal_model_471085845 Progress: [4/10]
# Cell: neuronal_model_471085845 Progress: [5/10]
# Cell: neuronal_model_471085845 Progress: [6/10]
# Cell: neuronal_model_471085845 Progress: [7/10]
# Cell: neuronal_model_471085845 Progress: [8/10]
# Cell: neuronal_model_471085845 Progress: [9/10]
# Cell: neuronal_model_471085845 Progress: [10/10]
# Done generating EAPs for neuronal_model_471085845
# Cell cell_models\mouse_VISp_L5\aspiny\neuronal_model_472299363 is aspiny
# Mechanisms already loaded from path: modfiles.  Aborting.
# Input weight: 0.25 - Num Spikes: 69
# Input weight: 0.0625 - Num Spikes: 26
# Extracellular simulation: cell_models\mouse_VISp_L5\aspiny\neuronal_model_472299363
# Seed = 0
# Mechanisms already loaded from path: modfiles.  Aborting.
# Cell neuronal_model_472299363 extracellular spikes to be simulated
# Pre-generating 1000000 random positions
# Cell: neuronal_model_472299363 Progress: [1/10]
# Cell: neuronal_model_472299363 Progress: [2/10]
# Cell: neuronal_model_472299363 Progress: [3/10]
# Cell: neuronal_model_472299363 Progress: [4/10]
# Cell: neuronal_model_472299363 Progress: [5/10]
# Cell: neuronal_model_472299363 Progress: [6/10]
# ...
# Extracellular simulation: cell_models\mouse_VISp_L5\aspiny\neuronal_model_480630211
# Seed = 0
# Mechanisms already loaded from path: modfiles.  Aborting.
# Cell neuronal_model_480630211 extracellular spikes to be simulated
# Pre-generating 1000000 random positions
# Cell: neuronal_model_480630211 Progress: [1/10]
# Cell: neuronal_model_480630211 Progress: [2/10]
# Cell: neuronal_model_480630211 Progress: [3/10]
# Cell: neuronal_model_480630211 Progress: [4/10]
# Cell: neuronal_model_480630211 Progress: [5/10]
# Cell: neuronal_model_480630211 Progress: [6/10]
# Cell: neuronal_model_480630211 Progress: [7/10]
# Cell: neuronal_model_480630211 Progress: [8/10]
# Cell: neuronal_model_480630211 Progress: [9/10]
# Cell: neuronal_model_480630211 Progress: [10/10]
# Done generating EAPs for neuronal_model_480630211
# Cell cell_models\mouse_VISp_L5\aspiny\neuronal_model_480631048 is aspiny
# Mechanisms already loaded from path: modfiles.  Aborting.
# warning reconstruction.swc: more than one tree:
#   root at line 4
#   root at line 5999
#   root at line 6829
#   root at line 6940
#   root at line 6954
#   root at line 6962
#   root at line 7198
#   root at line 7206
#   root at line 7222
#   root at line 7335
#   root at line 7372
#   root at line 7414
#   root at line 7484
#   root at line 7552
#   root at line 7571
#   root at line 7663
#   root at line 7676
#   root at line 7713
#   root at line 7723
#   root at line 7739
#   root at line 7992
#   root at line 8084
#   root at line 8153
#   root at line 8164
#   root at line 8173
#   root at line 8218
#   root at line 8266
#   root at line 8298
#   root at line 8360
#   root at line 8365
#   root at line 8419
#   root at line 8432
#   root at line 8443
#   root at line 8493
#   root at line 8508
#   root at line 8596
#   root at line 8615
#   root at line 8649
#   root at line 9152
#   root at line 9334
#   root at line 9586
#   root at line 9599
#   root at line 9678
# Input weight: 0.25 - Num Spikes: 0
# Input weight: 0.4375 - Num Spikes: 0
# Input weight: 0.765625 - Num Spikes: 1
# Input weight: 1.33984375 - Num Spikes: 1
# Input weight: 2.3447265625 - Num Spikes: 1
# Input weight: 4.103271484375 - Num Spikes: 1
# Input weight: 7.18072509765625 - Num Spikes: 2
# Input weight: 12.566268920898438 - Num Spikes: 1
# Input weight: 21.990970611572266 - Num Spikes: 1
# Input weight: 38.484198570251465 - Num Spikes: 1
# Cell cell_models\mouse_VISp_L5\aspiny\neuronal_model_480631048 is bad. Excluded..
# Cell cell_models\mouse_VISp_L5\aspiny\neuronal_model_480631286 is aspiny
# Mechanisms already loaded from path: modfiles.  Aborting.
# Input weight: 0.25 - Num Spikes: 79
# Input weight: 0.0625 - Num Spikes: 0
# Input weight: 0.109375 - Num Spikes: 0
# Input weight: 0.19140625 - Num Spikes: 50
# Extracellular simulation: cell_models\mouse_VISp_L5\aspiny\neuronal_model_480631286
# Seed = 0
# Mechanisms already loaded from path: modfiles.  Aborting.
# Cell neuronal_model_480631286 extracellular spikes to be simulated
# Pre-generating 1000000 random positions
# Cell: neuronal_model_480631286 Progress: [1/10]
# Cell: neuronal_model_480631286 Progress: [2/10]
# Cell: neuronal_model_480631286 Progress: [3/10]
# Cell: neuronal_model_480631286 Progress: [4/10]
# Cell: neuronal_model_480631286 Progress: [5/10]
# Cell: neuronal_model_480631286 Progress: [6/10]
# Cell: neuronal_model_480631286 Progress: [7/10]
# Cell: neuronal_model_480631286 Progress: [8/10]
# Cell: neuronal_model_480631286 Progress: [9/10]
# Cell: neuronal_model_480631286 Progress: [10/10]
# Done generating EAPs for neuronal_model_480631286
# Cell cell_models\mouse_VISp_L5\aspiny\neuronal_model_483066358 is aspiny
# Mechanisms already loaded from path: modfiles.  Aborting.
# Input weight: 0.25 - Num Spikes: 105
# Input weight: 0.0625 - Num Spikes: 12
# Extracellular simulation: cell_models\mouse_VISp_L5\aspiny\neuronal_model_483066358
# Seed = 0
# Mechanisms already loaded from path: modfiles.  Aborting.
# Cell neuronal_model_483066358 extracellular spikes to be simulated
# Pre-generating 1000000 random positions
# Cell: neuronal_model_483066358 Progress: [1/10]
# Cell: neuronal_model_483066358 Progress: [2/10]
# Cell: neuronal_model_483066358 Progress: [3/10]
# Cell: neuronal_model_483066358 Progress: [4/10]
# Cell: neuronal_model_483066358 Progress: [5/10]
# Cell: neuronal_model_483066358 Progress: [6/10]
# Cell: neuronal_model_483066358 Progress: [7/10]
# Cell: neuronal_model_483066358 Progress: [8/10]
# Cell: neuronal_model_483066358 Progress: [9/10]
# Cell: neuronal_model_483066358 Progress: [10/10]
# Done generating EAPs for neuronal_model_483066358
# Cell cell_models\mouse_VISp_L5\aspiny\neuronal_model_483106906 is aspiny
# Mechanisms already loaded from path: modfiles.  Aborting.
# warning reconstruction.swc: more than one tree:
#   root at line 2
#   root at line 5836
#   root at line 6575
#   root at line 7109
#   root at line 7231
#   root at line 7747
#   root at line 7852
#   root at line 7965
#   root at line 8511
#   root at line 8556
#   root at line 8698
#   root at line 8837
#   root at line 8873
#   root at line 8890
#   root at line 8965
#   root at line 9071
#   root at line 9114
#   root at line 9123
#   root at line 9142
#   root at line 9173
#   root at line 9244
#   root at line 9281
#   root at line 9302
# Input weight: 0.25 - Num Spikes: 0
# Input weight: 0.4375 - Num Spikes: 0
# Input weight: 0.765625 - Num Spikes: 1
# Input weight: 1.33984375 - Num Spikes: 1
# Input weight: 2.3447265625 - Num Spikes: 1
# Input weight: 4.103271484375 - Num Spikes: 1
# Input weight: 7.18072509765625 - Num Spikes: 3
# Input weight: 12.566268920898438 - Num Spikes: 1
# Input weight: 21.990970611572266 - Num Spikes: 1
# Input weight: 38.484198570251465 - Num Spikes: 1
# Cell cell_models\mouse_VISp_L5\aspiny\neuronal_model_483106906 is bad. Excluded..
# Cell cell_models\mouse_VISp_L5\aspiny\neuronal_model_484620556 is aspiny
# Mechanisms already loaded from path: modfiles.  Aborting.
# Input weight: 0.25 - Num Spikes: 1
# Input weight: 0.4375 - Num Spikes: 121
# Input weight: 0.109375 - Num Spikes: 0
# Input weight: 0.19140625 - Num Spikes: 0
# Input weight: 0.3349609375 - Num Spikes: 86
# Input weight: 0.083740234375 - Num Spikes: 0
# Input weight: 0.14654541015625 - Num Spikes: 0
# Input weight: 0.2564544677734375 - Num Spikes: 1
# Input weight: 0.4487953186035156 - Num Spikes: 124
# Input weight: 0.1121988296508789 - Num Spikes: 0
# Cell cell_models\mouse_VISp_L5\aspiny\neuronal_model_484620556 is bad. Excluded..
# Cell cell_models\mouse_VISp_L5\aspiny\neuronal_model_484628276 is aspiny
# Mechanisms already loaded from path: modfiles.  Aborting.
# Input weight: 0.25 - Num Spikes: 115
# Input weight: 0.0625 - Num Spikes: 39
# Extracellular simulation: cell_models\mouse_VISp_L5\aspiny\neuronal_model_484628276
# Seed = 0
# Mechanisms already loaded from path: modfiles.  Aborting.
# Cell neuronal_model_484628276 extracellular spikes to be simulated
# Pre-generating 1000000 random positions
# Cell: neuronal_model_484628276 Progress: [1/10]
# Cell: neuronal_model_484628276 Progress: [2/10]
# Cell: neuronal_model_484628276 Progress: [3/10]
# Cell: neuronal_model_484628276 Progress: [4/10]
# Cell: neuronal_model_484628276 Progress: [5/10]
# Cell: neuronal_model_484628276 Progress: [6/10]
# Cell: neuronal_model_484628276 Progress: [7/10]
# Cell: neuronal_model_484628276 Progress: [8/10]
# Cell: neuronal_model_484628276 Progress: [9/10]
# Cell: neuronal_model_484628276 Progress: [10/10]
# Done generating EAPs for neuronal_model_484628276
# Cell cell_models\mouse_VISp_L5\aspiny\neuronal_model_485476031 is aspiny
# Mechanisms already loaded from path: modfiles.  Aborting.
# warning reconstruction.swc: more than one tree:
#   root at line 4
#   root at line 9738
#   root at line 9761
#   root at line 9969
#   root at line 10023
#   root at line 10325
#   root at line 10376
#   root at line 10684
#   root at line 10709
#   root at line 10748
#   root at line 10762
#   root at line 10788
#   root at line 10808
#   root at line 10958
#   root at line 10973
#   root at line 10983
#   root at line 10991
#   root at line 10997
#   root at line 11002
#   root at line 11084
#   root at line 11109
#   root at line 11120
#   root at line 11162
#   root at line 11185
#   root at line 11210
#   root at line 11278
# Input weight: 0.25 - Num Spikes: 0
# Input weight: 0.4375 - Num Spikes: 0
# Input weight: 0.765625 - Num Spikes: 0
# Input weight: 1.33984375 - Num Spikes: 1
# Input weight: 2.3447265625 - Num Spikes: 2
# Input weight: 4.103271484375 - Num Spikes: 1
# Input weight: 7.18072509765625 - Num Spikes: 1
# Input weight: 12.566268920898438 - Num Spikes: 1
# Input weight: 21.990970611572266 - Num Spikes: 1
# Input weight: 38.484198570251465 - Num Spikes: 1
# Cell cell_models\mouse_VISp_L5\aspiny\neuronal_model_485476031 is bad. Excluded..
# Cell cell_models\mouse_VISp_L5\aspiny\neuronal_model_485513255 is aspiny
# Mechanisms already loaded from path: modfiles.  Aborting.
# Input weight: 0.25 - Num Spikes: 70
# Input weight: 0.0625 - Num Spikes: 0
# Input weight: 0.109375 - Num Spikes: 39
# Extracellular simulation: cell_models\mouse_VISp_L5\aspiny\neuronal_model_485513255
# Seed = 0
# Mechanisms already loaded from path: modfiles.  Aborting.
# Cell neuronal_model_485513255 extracellular spikes to be simulated
# Pre-generating 1000000 random positions
# Cell: neuronal_model_485513255 Progress: [1/10]
# Cell: neuronal_model_485513255 Progress: [2/10]
# Cell: neuronal_model_485513255 Progress: [3/10]
# Cell: neuronal_model_485513255 Progress: [4/10]
# Cell: neuronal_model_485513255 Progress: [5/10]
# Cell: neuronal_model_485513255 Progress: [6/10]
# Cell: neuronal_model_485513255 Progress: [7/10]
# Cell: neuronal_model_485513255 Progress: [8/10]
# Cell: neuronal_model_485513255 Progress: [9/10]
# Cell: neuronal_model_485513255 Progress: [10/10]
# Done generating EAPs for neuronal_model_485513255
# Cell cell_models\mouse_VISp_L5\aspiny\neuronal_model_485611914 is aspiny
# Mechanisms already loaded from path: modfiles.  Aborting.
# Input weight: 0.25 - Num Spikes: 94
# Input weight: 0.0625 - Num Spikes: 0
# Input weight: 0.109375 - Num Spikes: 38
# Extracellular simulation: cell_models\mouse_VISp_L5\aspiny\neuronal_model_485611914
# Seed = 0
# Mechanisms already loaded from path: modfiles.  Aborting.
# Cell neuronal_model_485611914 extracellular spikes to be simulated
# Pre-generating 1000000 random positions
# Cell: neuronal_model_485611914 Progress: [1/10]
# Cell: neuronal_model_485611914 Progress: [2/10]
# Cell: neuronal_model_485611914 Progress: [3/10]
# Cell: neuronal_model_485611914 Progress: [4/10]
# Cell: neuronal_model_485611914 Progress: [5/10]
# Cell: neuronal_model_485611914 Progress: [6/10]
# Cell: neuronal_model_485611914 Progress: [7/10]
# Cell: neuronal_model_485611914 Progress: [8/10]
# Cell: neuronal_model_485611914 Progress: [9/10]
# Cell: neuronal_model_485611914 Progress: [10/10]
# Done generating EAPs for neuronal_model_485611914
# Cell cell_models\mouse_VISp_L5\aspiny\neuronal_model_485904766 is aspiny
# Mechanisms already loaded from path: modfiles.  Aborting.
# Input weight: 0.25 - Num Spikes: 1
# Input weight: 0.4375 - Num Spikes: 2
# Input weight: 0.765625 - Num Spikes: 2
# Input weight: 1.33984375 - Num Spikes: 2
# Input weight: 2.3447265625 - Num Spikes: 1
# Input weight: 4.103271484375 - Num Spikes: 1
# Input weight: 7.18072509765625 - Num Spikes: 1
# Input weight: 12.566268920898438 - Num Spikes: 1
# Input weight: 21.990970611572266 - Num Spikes: 1
# Input weight: 38.484198570251465 - Num Spikes: 1
# Cell cell_models\mouse_VISp_L5\aspiny\neuronal_model_485904766 is bad. Excluded..
# Cell cell_models\mouse_VISp_L5\aspiny\neuronal_model_486144663 is aspiny
# Mechanisms already loaded from path: modfiles.  Aborting.
# Input weight: 0.25 - Num Spikes: 149
# Input weight: 0.0625 - Num Spikes: 38
# Extracellular simulation: cell_models\mouse_VISp_L5\aspiny\neuronal_model_486144663
# Seed = 0
# Mechanisms already loaded from path: modfiles.  Aborting.
# Cell neuronal_model_486144663 extracellular spikes to be simulated
# Pre-generating 1000000 random positions
# Cell: neuronal_model_486144663 Progress: [1/10]
# Cell: neuronal_model_486144663 Progress: [2/10]
# Cell: neuronal_model_486144663 Progress: [3/10]
# Cell: neuronal_model_486144663 Progress: [4/10]
# Cell: neuronal_model_486144663 Progress: [5/10]
# Cell: neuronal_model_486144663 Progress: [6/10]
# Cell: neuronal_model_486144663 Progress: [7/10]
# Cell: neuronal_model_486144663 Progress: [8/10]
# Cell: neuronal_model_486144663 Progress: [9/10]
# Cell: neuronal_model_486144663 Progress: [10/10]
# Done generating EAPs for neuronal_model_486144663
# Cell cell_models\mouse_VISp_L5\aspiny\neuronal_model_487245869 is aspiny
# Mechanisms already loaded from path: modfiles.  Aborting.
# Input weight: 0.25 - Num Spikes: 65
# Input weight: 0.0625 - Num Spikes: 0
# Input weight: 0.109375 - Num Spikes: 14
# Extracellular simulation: cell_models\mouse_VISp_L5\aspiny\neuronal_model_487245869
# Seed = 0
# Mechanisms already loaded from path: modfiles.  Aborting.
# Cell neuronal_model_487245869 extracellular spikes to be simulated
# Pre-generating 1000000 random positions
# Cell: neuronal_model_487245869 Progress: [1/10]
# Cell: neuronal_model_487245869 Progress: [2/10]
# Cell: neuronal_model_487245869 Progress: [3/10]
# Cell: neuronal_model_487245869 Progress: [4/10]
# Cell: neuronal_model_487245869 Progress: [5/10]
# Cell: neuronal_model_487245869 Progress: [6/10]
# Cell: neuronal_model_487245869 Progress: [7/10]
# Cell: neuronal_model_487245869 Progress: [8/10]
# Cell: neuronal_model_487245869 Progress: [9/10]
# Cell: neuronal_model_487245869 Progress: [10/10]
# Done generating EAPs for neuronal_model_487245869
# Cell cell_models\mouse_VISp_L5\aspiny\neuronal_model_491623973 is aspiny
# Mechanisms already loaded from path: modfiles.  Aborting.
# warning reconstruction.swc: more than one tree:
#   root at line 4
#   root at line 5019
#   root at line 5524
#   root at line 5599
#   root at line 5624
#   root at line 5739
#   root at line 6205
#   root at line 7397
#   root at line 7801
#   root at line 7920
#   root at line 7999
#   root at line 8961
#   root at line 8964
#   root at line 9124
#   root at line 9429
#   root at line 9503
#   root at line 9531
#   root at line 9541
#   root at line 9905
#   root at line 9945
#   root at line 9967
#   root at line 10018
#   root at line 10060
#   root at line 10150
#   root at line 10205
#   root at line 10215
#   root at line 10228
#   root at line 10305
#   root at line 10623
#   root at line 10690
#   root at line 10789
#   root at line 10822
#   root at line 10882
#   root at line 10892
#   root at line 10897
#   root at line 10996
#   root at line 11067
#   root at line 11092
# Input weight: 0.25 - Num Spikes: 0
# Input weight: 0.4375 - Num Spikes: 0
# Input weight: 0.765625 - Num Spikes: 0
# Input weight: 1.33984375 - Num Spikes: 1
# Input weight: 2.3447265625 - Num Spikes: 1
# Input weight: 4.103271484375 - Num Spikes: 1
# Input weight: 7.18072509765625 - Num Spikes: 1
# Input weight: 12.566268920898438 - Num Spikes: 3
# Input weight: 21.990970611572266 - Num Spikes: 1
# Input weight: 38.484198570251465 - Num Spikes: 1
# Cell cell_models\mouse_VISp_L5\aspiny\neuronal_model_491623973 is bad. Excluded..
# Cell cell_models\mouse_VISp_L5\aspiny\neuronal_model_496930338 is aspiny
# Mechanisms already loaded from path: modfiles.  Aborting.
# Input weight: 0.25 - Num Spikes: 87
# Input weight: 0.0625 - Num Spikes: 0
# Input weight: 0.109375 - Num Spikes: 0
# Input weight: 0.19140625 - Num Spikes: 63
# Input weight: 0.0478515625 - Num Spikes: 0
# Input weight: 0.083740234375 - Num Spikes: 0
# Input weight: 0.14654541015625 - Num Spikes: 34
# Extracellular simulation: cell_models\mouse_VISp_L5\aspiny\neuronal_model_496930338
# Seed = 0
# Mechanisms already loaded from path: modfiles.  Aborting.
# Cell neuronal_model_496930338 extracellular spikes to be simulated
# Pre-generating 1000000 random positions
# Cell: neuronal_model_496930338 Progress: [1/10]
# Cell: neuronal_model_496930338 Progress: [2/10]
# Cell: neuronal_model_496930338 Progress: [3/10]
# Cell: neuronal_model_496930338 Progress: [4/10]
# Cell: neuronal_model_496930338 Progress: [5/10]
# Cell: neuronal_model_496930338 Progress: [6/10]
# Cell: neuronal_model_496930338 Progress: [7/10]
# Cell: neuronal_model_496930338 Progress: [8/10]
# Cell: neuronal_model_496930338 Progress: [9/10]
# Cell: neuronal_model_496930338 Progress: [10/10]
# Done generating EAPs for neuronal_model_496930338
# (600, 30, 128, 224)
# (600, 30, 3)
# (600, 3)
# (600,)
#
# Saved  templates in studies\mouse_VISp_L5_128ch\templates\template_drift\templates.h5

# %% [markdown]
# Then generate recordings using this template. Set up the parameters for generating recordings.

# %%
### rec_params with drifting

# get default
rec_params = mr.get_default_recordings_params()

rec_params['cell_types'] = {'excitatory': ['spiny','sparsely_spiny'], 'inhibitory': ['aspiny']}

rec_params['spiketrains']['n_exc'] = 40 # int, number of excitatory cells, less than number of templates
rec_params['spiketrains']['n_inh'] = 20 # int, number of inhibitory cells
rec_params['spiketrains']['f_exc'] = 5 # float, average firing rate of exc cells (Hz)
rec_params['spiketrains']['f_inh'] = 15 # float, average firing rate of inh cells (Hz)
rec_params['spiketrains']['st_exc'] = 1 # float, firing rate standard deviation of exc cells
rec_params['spiketrains']['st_inh'] = 3 # float, firing rate standard deviation of inh cells
rec_params['spiketrains']['min_rate'] = 0.5 # float, min firing rate (Hz)
rec_params['spiketrains']['ref_per'] = 2 # float, refractory period (msec)
rec_params['spiketrains']['process'] = 'poisson' # process of spike train simulation, ['poisson','gamma']
rec_params['spiketrains']['gamma_shape'] = 2 # gamma shape for gamma process
rec_params['spiketrains']['duration'] = 30 # float, recording time

rec_params['templates']['min_dist'] = 25 # float, min distance between cells
rec_params['templates']['min_amp'] = 50 # float, min spike amplitude (uV)
rec_params['templates']['max_amp'] = 500 # float, max spike amplitude (uV)
rec_params['templates']['xlim'] = None # limits of neurons in x-axis
rec_params['templates']['ylim'] = None # limits of neurons in y-axis
rec_params['templates']['zlim'] = None # limits of neurons in z-axis
rec_params['templates']['overlap_threshold'] = 0.9 # float, threshold to consider 2 templates spatially overlapping
rec_params['templates']['n_jitters'] = 10 # int, number of temporal jittered copies for each template (temporal shift within one sampling period)
rec_params['templates']['upsample'] = 8 # int, upsampling factor to extract jittered copies
rec_params['templates']['pad_len'] = [3,3] # float, pre/post time padding of templates (msec)

rec_params['recordings']['fs'] = None # if None, computed from templates
rec_params['recordings']['dtype'] = 'float32'
rec_params['recordings']['overlap'] = True # compute temporal and spatial overlap for each spike
rec_params['recordings']['extract_waveforms'] = True # extract waveforms from recordings
rec_params['recordings']['sync_rate'] = 0.05 # sync rate 0-1 for spatially overlapping templates
rec_params['recordings']['sync_jitt'] = 1 # float, jitter for added sync spikes (msec)
rec_params['recordings']['modulation'] = 'electrode' # type of spike modulation ['none','template','electrode'] 'template': same value on each electrode; 'electrode': different value on each electrode
rec_params['recordings']['sdrand'] = 0.05 # float, standard deviation of Guassian modulation, when bursting is False

rec_params['recordings']['bursting'] = True # modulate spikes in amplitude depending on ISI
rec_params['recordings']['exp_decay'] = 0.1 # float, when bursting is True, decay in amplitude between consecutive spikes
rec_params['recordings']['n_burst_spikes'] = 10 # int, max bursting consecutive spikes
rec_params['recordings']['max_burst_duration'] = 100 # float, max burst modulation time (msec)
rec_params['recordings']['shape_mod'] = True # stretch spike shapes with sigmoid transform
rec_params['recordings']['shape_stretch'] = 30 # float, amount of stretch for shape modulation
rec_params['recordings']['n_bursting'] = None # int, number of bursting cells, if None, all are bursting
rec_params['recordings']['chunk_duration'] = 20 # sec, processing chunk

rec_params['recordings']['noise_mode'] = 'distance-correlated' # ['uncorrelated','distance-correlated','far-neurons']
rec_params['recordings']['noise_level'] = 10 # float, noise standard deviation (uV)
rec_params['recordings']['noise_color'] = True # have colored noise
rec_params['recordings']['noise_half_distance'] = 30 # distance (um) between electrodes for which correlation is 0.5
rec_params['recordings']['color_peak'] = 300 # peak/cutoff frequency for colored noise (Hz)
rec_params['recordings']['color_q'] = 2 # quality factor for colored noise
rec_params['recordings']['color_noise_floor'] = 0.5 # percent of addictive noise for colored noise
rec_params['recordings']['far_neurons_n'] = 300 # number of far neurons to be simulated
rec_params['recordings']['far_neurons_max_amp'] = 10 # max amplitude of far neurons
rec_params['recordings']['far_neurons_noise_floor'] = 0.5 # percent of addictive noise for far-neurons noise
rec_params['recordings']['far_neurons_exc_inh_ratio'] = 0.8 # e/i noisy neuron ratio 0-1

rec_params['recordings']['filter'] = False # filter the recording
rec_params['recordings']['filter_cutoff'] = [300,6000]
rec_params['recordings']['filter_order'] = 3

rec_params['recordings']['drifting'] = True # simulate drifting recordings
rec_params['recordings']['n_drifting'] = None # number of drifting cells, if None, all are drifting
rec_params['recordings']['perferred_dir'] = [0,0,1] # drifting direction, positive z-axis
rec_params['recordings']['angle_tol'] = 90 # tolerance for direction (degree)
rec_params['recordings']['slow_drift_velocity'] = 5 # slow drift (um/min)
rec_params['recordings']['fast_drift_period'] = 20 # period between fast drift (sec)
rec_params['recordings']['fast_drift_max_jump'] = 20 # max amplitude jump for fast drifts (uV)
rec_params['recordings']['fast_drift_min_jump'] = 5 # min amplitude jump for fast drift
rec_params['recordings']['t_start_drift'] = 0 # when start drifting (sec)

rec_params['seeds']['spiketrains'] = None
rec_params['seeds']['templates'] = None
rec_params['seeds']['convolution'] = None
rec_params['seeds']['noise'] = None

# %% [markdown]
# Generate recordings.

# %%
recording_path = create_empty_recordings(study_path,'recording_drift')

# save template_params
with open((recording_path / 'recording_params.pkl').as_posix(), 'wb') as f:
    pkl.dump(rec_params,f)

generate_recording(rec_params, template_path, recording_path)
# Out:
# {'cell_types': {'excitatory': ['spiny', 'sparsely_spiny'],
#                 'inhibitory': ['aspiny']},
#  'recordings': {'adc_bit_depth': None,
#                 'angle_tol': 90,
#                 'bursting': True,
#                 'bursting_units': None,
#                 'chunk_duration': 20,
#                 'color_noise_floor': 0.5,
#                 'color_peak': 300,
#                 'color_q': 2,
#                 'drift_fs': 100,
#                 'drift_mode_probe': 'rigid',
#                 'drift_mode_speed': 'slow',
#                 'drifting': True,
#                 'dtype': 'float32',
#                 'exp_decay': 0.1,
#                 'extract_waveforms': True,
#                 'far_neurons_exc_inh_ratio': 0.8,
#                 'far_neurons_max_amp': 10,
#                 'far_neurons_n': 300,
#                 'far_neurons_noise_floor': 0.5,
#                 'fast_drift_max_jump': 20,
#                 'fast_drift_min_jump': 5,
#                 'fast_drift_period': 20,
#                 'filter': False,
#                 'filter_cutoff': [300, 6000],
#                 'filter_order': 3,
#                 'fs': None,
#                 'gain': None,
#                 'lsb': None,
#                 'max_burst_duration': 100,
#                 'modulation': 'electrode',
#                 'n_burst_spikes': 10,
#                 'n_bursting': None,
#                 'n_drifting': None,
#                 'noise_color': True,
#                 'noise_half_distance': 30,
#                 'noise_level': 10,
#                 'noise_mode': 'distance-correlated',
#                 'non_rigid_gradient_mode': 'linear',
#                 'overlap': True,
#                 'perferred_dir': [0, 0, 1],
#                 'preferred_dir': [0, 0, 1],
#                 'sdrand': 0.05,
#                 'shape_mod': True,
#                 'shape_stretch': 30,
#                 'slow_drift_amplitude': None,
#                 'slow_drift_velocity': 5,
#                 'slow_drift_waveform': 'triangluar',
#                 'sync_jitt': 1,
#                 'sync_rate': 0.05,
#                 't_end_drift': None,
#                 't_start_drift': 0},
#  'seeds': {'convolution': None,
#            'noise': None,
#            'spiketrains': None,
#            'templates': None},
#  'spiketrains': {'duration': 30,
#                  'f_exc': 5,
#                  'f_inh': 15,
#                  'gamma_shape': 2,
#                  'min_rate': 0.5,
#                  'n_exc': 40,
#                  'n_inh': 20,
#                  'process': 'poisson',
#                  'ref_per': 2,
#                  'st_exc': 1,
#                  'st_inh': 3,
#                  't_start': 0},
#  'templates': {'max_amp': 500,
#                'min_amp': 50,
#                'min_dist': 25,
#                'n_jitters': 10,
#                'n_overlap_pairs': None,
#                'overlap_threshold': 0.9,
#                'pad_len': [3, 3],
#                'smooth_percent': 0.5,
#                'smooth_strength': 1,
#                'upsample': 8,
#                'xlim': None,
#                'ylim': None,
#                'zlim': None}}
# Loading templates...
# Done loading templates...
# Spiketrains seed:  7370
# dtype float32
# Noise Level  10
# Bursting with modulation sigmoid:  30
# Templates selection seed:  995
# Selecting cells
# Selecting random templates (cell types not specified)
# Min dist:  25 Min amp:  50
# Amplitude or boundary violation 42.904257991605085 [ 21.12787086 -23.88010121 437.53883293] 5
# Amplitude or boundary violation 42.1247009313632 [ 28.51889285  -3.36179924 142.79536955] 8
# Amplitude or boundary violation 37.61506650149543 [ 13.80365918  15.93823665 354.83287805] 10
# Amplitude or boundary violation 42.41298980720799 [  42.30355536   20.23168439 -126.88842988] 19
# Distance violation 10.47491324799155 23
# Amplitude or boundary violation 41.558536965051125 [  18.27920981  -23.68701806 -326.67841476] 25
# Distance violation 18.883973872273152 26
# Amplitude or boundary violation 41.00738894075739 [  24.62137293   19.28459522 -434.73077508] 27
# Amplitude or boundary violation 36.67510066545621 [17.01588211 -9.60325158 94.86168698] 28
# Amplitude or boundary violation 30.444430206945977 [  32.07998456   -9.15809906 -107.51754413] 29
# Amplitude or boundary violation 35.52912356412823 [ 39.0263358  -14.04075095 248.9445435 ] 30
# Amplitude or boundary violation 48.73887673529613 [ 21.12787086 -23.88010121 437.53883293] 31
# Amplitude or boundary violation 38.103687331609336 [ 16.57583575   7.64341099 412.06467467] 32
# Distance violation 0.0 33
# Amplitude or boundary violation 48.961158086313894 [  16.72688855  -25.751617   -443.78082954] 34
# Distance violation 18.847001021914732 35
# Amplitude or boundary violation 43.74186354924565 [ 16.79708931   7.82712778 266.73882677] 46
# Distance violation 14.404792492746552 47
# Amplitude or boundary violation 48.702533982410245 [  46.52938252    4.29979691 -307.05292236] 48
# Amplitude or boundary violation 36.060185207664816 [  18.41375928   22.80843724 -257.60460456] 49
# Amplitude or boundary violation 43.36805148733311 [  42.30355536   20.23168439 -126.88842988] 50
# Amplitude or boundary violation 45.24466793685426 [ 28.51889285  -3.36179924 142.79536955] 51
# Amplitude or boundary violation 36.14239409385001 [  24.62137293   19.28459522 -434.73077508] 55
# Amplitude or boundary violation 37.08301373871012 [ 14.97252407 -36.07027824 467.4922171 ] 58
# Amplitude or boundary violation 36.84715519008624 [ 10.81998589  22.00464979 459.86164103] 60
# Amplitude or boundary violation 37.64721914948734 [ 17.14313675  -8.63800579 304.15522379] 61
# Amplitude or boundary violation 43.88143981508243 [ 16.57583575   7.64341099 412.06467467] 62
# Distance violation 24.93337092666553 65
# Amplitude or boundary violation 41.24015424332436 [  42.30355536   20.23168439 -126.88842988] 66
# Amplitude or boundary violation 45.151331595235156 [ 16.79708931   7.82712778 266.73882677] 68
# Amplitude or boundary violation 32.809723796460844 [ 21.12787086 -23.88010121 437.53883293] 72
# Distance violation 13.285639112648367 74
# Amplitude or boundary violation 36.16869089343795 [17.01588211 -9.60325158 94.86168698] 77
# Distance violation 0.0 78
# Amplitude or boundary violation 43.03718966232691 [  10.32868333   29.23119589 -162.22175725] 81
# Amplitude or boundary violation 32.399868181523075 [  17.72625988  -35.03975793 -407.96106908] 83
# Amplitude or boundary violation 48.254494788528895 [  36.84090632    8.97296704 -337.25909157] 85
# Amplitude or boundary violation 31.218007282821592 [  42.30355536   20.23168439 -126.88842988] 86
# Distance violation 21.68564814450249 87
# Distance violation 17.298110674916515 89
# Amplitude or boundary violation 36.17417047075622 [ 11.72751099   0.47756045 178.35034106] 95
# Amplitude or boundary violation 34.31457180902894 [ 17.14313675  -8.63800579 304.15522379] 98
# Distance violation 21.23202424681511 100
# Distance violation 23.49490094797864 101
# Num. of drift vectors shape 1 with [3000] samples
# Padding template edges
# Padding with 4 jobs
# Elapsed pad time: 42.559346199035645
# Creating time jittering
# Jittering with 4 jobs
# Elapsed jitter time: 103.48653149604797
# Smoothing templates
# Modifying synchrony of spatially overlapping spikes
# Overlapping templates:  [[ 0 35]
#  [ 0 42]
#  [ 0 44]
#  [ 2  5]
#  [ 2 19]
#  [ 2 28]
#  [ 2 46]
#  [ 2 55]
#  [ 3 18]
#  [ 3 25]
#  [ 3 26]
#  [ 3 50]
#  [ 3 56]
#  [ 3 59]
#  [ 4 11]
#  [ 4 39]
#  [ 4 41]
#  [ 4 49]
#  [ 5 19]
#  [ 5 28]
#  [ 5 46]
#  [ 5 55]
#  [ 6  9]
#  [ 6 14]
#  [ 7  8]
#  [ 7 15]
#  [ 7 23]
#  [ 7 24]
#  [ 7 27]
#  [ 7 37]
#  [ 7 38]
#  [ 8 15]
#  [ 8 23]
#  [ 8 24]
#  [ 8 27]
#  [ 8 37]
#  [ 8 38]
#  [ 9 14]
#  [10 43]
#  [10 57]
#  [11 39]
#  [11 41]
#  [11 49]
#  [12 22]
#  [12 53]
#  [13 33]
#  [13 47]
#  [13 48]
#  [15 23]
#  [15 24]
#  [15 27]
#  [15 37]
#  [15 38]
#  [16 39]
#  [16 49]
#  [17 20]
#  [17 31]
#  [17 40]
#  [18 25]
#  [18 26]
#  [18 50]
#  [18 56]
#  [18 59]
#  [19 28]
#  [19 46]
#  [19 55]
#  [20 31]
#  [20 40]
#  [21 37]
#  [22 53]
#  [23 24]
#  [23 27]
#  [23 37]
#  [23 38]
#  [24 27]
#  [24 37]
#  [24 38]
#  [25 26]
#  [25 50]
#  [25 56]
#  [25 59]
#  [26 50]
#  [26 56]
#  [26 59]
#  [27 37]
#  [27 38]
#  [28 46]
#  [28 55]
#  [29 36]
#  [29 58]
#  [31 40]
#  [33 47]
#  [33 48]
#  [35 42]
#  [35 44]
#  [36 58]
#  [37 38]
#  [39 49]
#  [39 41]
#  [41 49]
#  [42 44]
#  [43 54]
#  [45 51]
#  [46 55]
#  [47 48]
#  [50 56]
#  [50 59]
#  [56 59]
#  [43 57]]
# Overlapping pair:  [ 0 35]
# Added 6 spikes to spike train 0 and 11 spikes to spike train 35 Sync rate: 0.051829268292682924
# Overlapping pair:  [ 0 42]
# Remove 1 violations from times2
# Added 6 spikes to spike train 0 and 25 spikes to spike train 42 Sync rate: 0.05023547880690738
# Overlapping pair:  [ 0 44]
# Remove 1 violations from times2
# Added 5 spikes to spike train 0 and 18 spikes to spike train 44 Sync rate: 0.05091649694501019
# Overlapping pair:  [2 5]
# Added 9 spikes to spike train 2 and 10 spikes to spike train 5 Sync rate: 0.05307262569832402
# Overlapping pair:  [ 2 19]
# Added 9 spikes to spike train 2 and 3 spikes to spike train 19 Sync rate: 0.05460750853242321
# Overlapping pair:  [ 2 28]
# Remove 1 violations from times1
# Added 6 spikes to spike train 2 and 7 spikes to spike train 28 Sync rate: 0.04941860465116279
# Overlapping pair:  [ 2 46]
# Remove 1 violations from times1
# Added 7 spikes to spike train 2 and 22 spikes to spike train 46 Sync rate: 0.051470588235294115
# Overlapping pair:  [ 2 55]
# Added 6 spikes to spike train 2 and 26 spikes to spike train 55 Sync rate: 0.05070422535211268
# Overlapping pair:  [ 3 18]
# Added 13 spikes to spike train 3 and 4 spikes to spike train 18 Sync rate: 0.05319148936170213
# Overlapping pair:  [ 3 25]
# Remove 1 violations from times2
# Added 13 spikes to spike train 3 and 7 spikes to spike train 25 Sync rate: 0.04906542056074766
# Overlapping pair:  [ 3 26]
# Added 7 spikes to spike train 3 and 10 spikes to spike train 26 Sync rate: 0.05232558139534884
# Overlapping pair:  [ 3 50]
# Remove 1 violations from times2
# Added 9 spikes to spike train 3 and 25 spikes to spike train 50 Sync rate: 0.050761421319796954
# Overlapping pair:  [ 3 56]
# Remove 1 violations from times2
# Added 12 spikes to spike train 3 and 17 spikes to spike train 56 Sync rate: 0.050505050505050504
# Overlapping pair:  [ 3 59]
# Added 20 spikes to spike train 3 and 4 spikes to spike train 59 Sync rate: 0.05122950819672131
# Overlapping pair:  [ 4 11]
# Added 4 spikes to spike train 4 and 10 spikes to spike train 11 Sync rate: 0.05405405405405406
# Overlapping pair:  [ 4 39]
# Remove 1 violations from times2
# Added 7 spikes to spike train 4 and 4 spikes to spike train 39 Sync rate: 0.048458149779735685
# Overlapping pair:  [ 4 41]
# Added 6 spikes to spike train 4 and 16 spikes to spike train 41 Sync rate: 0.05106382978723404
# Overlapping pair:  [ 4 49]
# Remove 1 violations from times1
# Added 6 spikes to spike train 4 and 21 spikes to spike train 49 Sync rate: 0.050173010380622836
# Overlapping pair:  [ 5 19]
# Remove 1 violations from times1
# Added 7 spikes to spike train 5 and 6 spikes to spike train 19 Sync rate: 0.049079754601226995
# Overlapping pair:  [ 5 28]
# Added 12 spikes to spike train 5 and 6 spikes to spike train 28 Sync rate: 0.05235602094240838
# Overlapping pair:  [ 5 46]
# Added 10 spikes to spike train 5 and 21 spikes to spike train 46 Sync rate: 0.051675977653631286
# Overlapping pair:  [ 5 55]
# Added 8 spikes to spike train 5 and 23 spikes to spike train 55 Sync rate: 0.05128205128205128
# Overlapping pair:  [6 9]
# Added 5 spikes to spike train 6 and 11 spikes to spike train 9 Sync rate: 0.05167173252279635
# Overlapping pair:  [ 6 14]
# Added 11 spikes to spike train 6 and 8 spikes to spike train 14 Sync rate: 0.05191256830601093
# Overlapping pair:  [7 8]
# Added 6 spikes to spike train 7 and 7 spikes to spike train 8 Sync rate: 0.053231939163498096
# Overlapping pair:  [ 7 15]
# Added 11 spikes to spike train 7 and 3 spikes to spike train 15 Sync rate: 0.05263157894736842
# Overlapping pair:  [ 7 23]
# Added 3 spikes to spike train 7 and 13 spikes to spike train 23 Sync rate: 0.05263157894736842
# Overlapping pair:  [ 7 24]
# Added 11 spikes to spike train 7 and 3 spikes to spike train 24 Sync rate: 0.053156146179401995
# Overlapping pair:  [ 7 27]
# Added 4 spikes to spike train 7 and 13 spikes to spike train 27 Sync rate: 0.05157593123209169
# Overlapping pair:  [ 7 37]
# Added 9 spikes to spike train 7 and 7 spikes to spike train 37 Sync rate: 0.052307692307692305
# Overlapping pair:  [ 7 38]
# Added 6 spikes to spike train 7 and 12 spikes to spike train 38 Sync rate: 0.05588235294117647
# Overlapping pair:  [ 8 15]
# Added 4 spikes to spike train 8 and 7 spikes to spike train 15 Sync rate: 0.05223880597014925
# Overlapping pair:  [ 8 23]
# Added 7 spikes to spike train 8 and 9 spikes to spike train 23 Sync rate: 0.052478134110787174
# Overlapping pair:  [ 8 24]
# Added 9 spikes to spike train 8 and 5 spikes to spike train 24 Sync rate: 0.05226480836236934
# Overlapping pair:  [ 8 27]
# Added 6 spikes to spike train 8 and 10 spikes to spike train 27 Sync rate: 0.05167173252279635
# Overlapping pair:  [ 8 37]
# Added 9 spikes to spike train 8 and 6 spikes to spike train 37 Sync rate: 0.05211726384364821
# Overlapping pair:  [ 8 38]
# Added 8 spikes to spike train 8 and 9 spikes to spike train 38 Sync rate: 0.05345911949685535
# Overlapping pair:  [ 9 14]
# Added 5 spikes to spike train 9 and 11 spikes to spike train 14 Sync rate: 0.051771117166212535
# Overlapping pair:  [10 43]
# Added 6 spikes to spike train 10 and 28 spikes to spike train 43 Sync rate: 0.051597051597051594
# Overlapping pair:  [10 57]
# Added 7 spikes to spike train 10 and 16 spikes to spike train 57 Sync rate: 0.05263157894736842
# Overlapping pair:  [11 39]
# Added 9 spikes to spike train 11 and 7 spikes to spike train 39 Sync rate: 0.05448717948717949
# Overlapping pair:  [11 41]
# Added 6 spikes to spike train 11 and 19 spikes to spike train 41 Sync rate: 0.05225225225225225
# Overlapping pair:  [11 49]
# Remove 1 violations from times2
# Added 8 spikes to spike train 11 and 24 spikes to spike train 49 Sync rate: 0.05239520958083832
# Overlapping pair:  [12 22]
# Added 8 spikes to spike train 12 and 7 spikes to spike train 22 Sync rate: 0.05434782608695652
# Overlapping pair:  [12 53]
# Added 9 spikes to spike train 12 and 20 spikes to spike train 53 Sync rate: 0.05108359133126935
# Overlapping pair:  [13 33]
# Added 8 spikes to spike train 13 and 6 spikes to spike train 33 Sync rate: 0.05338078291814947
# Overlapping pair:  [13 47]
# Remove 1 violations from times2
# Added 7 spikes to spike train 13 and 25 spikes to spike train 47 Sync rate: 0.05078125
# Overlapping pair:  [13 48]
# Added 3 spikes to spike train 13 and 25 spikes to spike train 48 Sync rate: 0.0530421216848674
# Overlapping pair:  [15 23]
# Added 6 spikes to spike train 15 and 8 spikes to spike train 23 Sync rate: 0.0521978021978022
# Overlapping pair:  [15 24]
# Remove 1 violations from times1
# Added 7 spikes to spike train 15 and 6 spikes to spike train 24 Sync rate: 0.05177993527508091
# Overlapping pair:  [15 27]
# Added 7 spikes to spike train 15 and 7 spikes to spike train 27 Sync rate: 0.05172413793103448
# Overlapping pair:  [15 37]
# Added 8 spikes to spike train 15 and 5 spikes to spike train 37 Sync rate: 0.05214723926380368
# Overlapping pair:  [15 38]
# Remove 1 violations from times2
# Added 8 spikes to spike train 15 and 6 spikes to spike train 38 Sync rate: 0.05405405405405406
# Overlapping pair:  [16 39]
# Added 8 spikes to spike train 16 and 5 spikes to spike train 39 Sync rate: 0.052830188679245285
# Overlapping pair:  [16 49]
# Added 5 spikes to spike train 16 and 21 spikes to spike train 49 Sync rate: 0.05201342281879195
# Overlapping pair:  [17 20]
# Added 6 spikes to spike train 17 and 9 spikes to spike train 20 Sync rate: 0.052805280528052806
# Overlapping pair:  [17 31]
# Added 6 spikes to spike train 17 and 7 spikes to spike train 31 Sync rate: 0.05373134328358209
# Overlapping pair:  [17 40]
# Added 8 spikes to spike train 17 and 16 spikes to spike train 40 Sync rate: 0.05175292153589316
# Overlapping pair:  [18 25]
# Added 14 spikes to spike train 18 and 3 spikes to spike train 25 Sync rate: 0.053475935828877004
# Overlapping pair:  [18 26]
# Added 8 spikes to spike train 18 and 5 spikes to spike train 26 Sync rate: 0.053763440860215055
# Overlapping pair:  [18 50]
# Remove 1 violations from times1
# Added 8 spikes to spike train 18 and 24 spikes to spike train 50 Sync rate: 0.049930651872399444
# Overlapping pair:  [18 56]
# Remove 1 violations from times1
# Remove 1 violations from times2
# Added 12 spikes to spike train 18 and 17 spikes to spike train 56 Sync rate: 0.04936305732484077
# Overlapping pair:  [18 59]
# Added 9 spikes to spike train 18 and 9 spikes to spike train 59 Sync rate: 0.051643192488262914
# Overlapping pair:  [19 28]
# Added 6 spikes to spike train 19 and 9 spikes to spike train 28 Sync rate: 0.052307692307692305
# Overlapping pair:  [19 46]
# Added 5 spikes to spike train 19 and 24 spikes to spike train 46 Sync rate: 0.05143721633888049
# Overlapping pair:  [19 55]
# Added 5 spikes to spike train 19 and 21 spikes to spike train 55 Sync rate: 0.05116959064327485
# Overlapping pair:  [20 31]
# Added 8 spikes to spike train 20 and 8 spikes to spike train 31 Sync rate: 0.05263157894736842
# Overlapping pair:  [20 40]
# Added 7 spikes to spike train 20 and 19 spikes to spike train 40 Sync rate: 0.050933786078098474
# Overlapping pair:  [21 37]
# Added 6 spikes to spike train 21 and 9 spikes to spike train 37 Sync rate: 0.05329153605015674
# Overlapping pair:  [22 53]
# Added 5 spikes to spike train 22 and 25 spikes to spike train 53 Sync rate: 0.05105105105105105
# Overlapping pair:  [23 24]
# Remove 1 violations from times1
# Added 6 spikes to spike train 23 and 12 spikes to spike train 24 Sync rate: 0.04935064935064935
# Overlapping pair:  [23 27]
# Added 12 spikes to spike train 23 and 6 spikes to spike train 27 Sync rate: 0.05128205128205128
# Overlapping pair:  [23 37]
# Added 8 spikes to spike train 23 and 9 spikes to spike train 37 Sync rate: 0.053268765133171914
# Overlapping pair:  [23 38]
# Added 10 spikes to spike train 23 and 7 spikes to spike train 38 Sync rate: 0.05275779376498801
# Overlapping pair:  [24 27]
# Added 4 spikes to spike train 24 and 4 spikes to spike train 27 Sync rate: 0.05191256830601093
# Overlapping pair:  [24 37]
# Added 5 spikes to spike train 24 and 8 spikes to spike train 37 Sync rate: 0.05142857142857143
# Overlapping pair:  [24 38]
# Added 7 spikes to spike train 24 and 8 spikes to spike train 38 Sync rate: 0.05322128851540616
# Overlapping pair:  [25 26]
# Added 9 spikes to spike train 25 and 5 spikes to spike train 26 Sync rate: 0.05232558139534884
# Overlapping pair:  [25 50]
# Remove 1 violations from times1
# Remove 1 violations from times2
# Added 7 spikes to spike train 25 and 21 spikes to spike train 50 Sync rate: 0.04871794871794872
# Overlapping pair:  [25 56]
# Added 17 spikes to spike train 25 and 14 spikes to spike train 56 Sync rate: 0.05172413793103448
# Overlapping pair:  [25 59]
# Added 11 spikes to spike train 25 and 11 spikes to spike train 59 Sync rate: 0.05102040816326531
# Overlapping pair:  [26 50]
# Remove 1 violations from times1
# Added 7 spikes to spike train 26 and 25 spikes to spike train 50 Sync rate: 0.050359712230215826
# Overlapping pair:  [26 56]
# Added 5 spikes to spike train 26 and 20 spikes to spike train 56 Sync rate: 0.05203252032520325
# Overlapping pair:  [26 59]
# Added 11 spikes to spike train 26 and 10 spikes to spike train 59 Sync rate: 0.05314009661835749
# Overlapping pair:  [27 37]
# Added 10 spikes to spike train 27 and 7 spikes to spike train 37 Sync rate: 0.05289672544080604
# Overlapping pair:  [27 38]
# Added 5 spikes to spike train 27 and 10 spikes to spike train 38 Sync rate: 0.05486284289276808
# Overlapping pair:  [28 46]
# Added 9 spikes to spike train 28 and 23 spikes to spike train 46 Sync rate: 0.051675977653631286
# Overlapping pair:  [28 55]
# Added 6 spikes to spike train 28 and 21 spikes to spike train 55 Sync rate: 0.051630434782608696
# Overlapping pair:  [29 36]
# Added 6 spikes to spike train 29 and 12 spikes to spike train 36 Sync rate: 0.05341246290801187
# Overlapping pair:  [29 58]
# Remove 1 violations from times2
# Added 7 spikes to spike train 29 and 27 spikes to spike train 58 Sync rate: 0.04955527318932656
# Overlapping pair:  [31 40]
# Added 8 spikes to spike train 31 and 16 spikes to spike train 40 Sync rate: 0.051696284329563816
# Overlapping pair:  [33 47]
# Remove 1 violations from times1
# Remove 1 violations from times2
# Added 4 spikes to spike train 33 and 30 spikes to spike train 47 Sync rate: 0.04864864864864865
# Overlapping pair:  [33 48]
# Added 10 spikes to spike train 33 and 19 spikes to spike train 48 Sync rate: 0.05211726384364821
# Overlapping pair:  [35 42]
# Added 8 spikes to spike train 35 and 22 spikes to spike train 42 Sync rate: 0.051075268817204304
# Overlapping pair:  [35 44]
# Added 11 spikes to spike train 35 and 13 spikes to spike train 44 Sync rate: 0.05201342281879195
# Overlapping pair:  [36 58]
# Added 7 spikes to spike train 36 and 27 spikes to spike train 58 Sync rate: 0.050697084917617236
# Overlapping pair:  [37 38]
# Added 5 spikes to spike train 37 and 9 spikes to spike train 38 Sync rate: 0.052083333333333336
# Overlapping pair:  [39 49]
# Remove 1 violations from times1
# Added 10 spikes to spike train 39 and 18 spikes to spike train 49 Sync rate: 0.05229793977812995
# Overlapping pair:  [39 41]
# Remove 1 violations from times1
# Added 6 spikes to spike train 39 and 14 spikes to spike train 41 Sync rate: 0.04945054945054945
# Overlapping pair:  [41 49]
# Added 15 spikes to spike train 41 and 12 spikes to spike train 49 Sync rate: 0.05098493626882966
# Overlapping pair:  [42 44]
# Remove 2 violations from times2
# Added 14 spikes to spike train 42 and 12 spikes to spike train 44 Sync rate: 0.04903078677309008
# Overlapping pair:  [43 54]
# Remove 1 violations from times1
# Added 25 spikes to spike train 43 and 17 spikes to spike train 54 Sync rate: 0.05094494658997535
# Overlapping pair:  [45 51]
# Added 15 spikes to spike train 45 and 15 spikes to spike train 51 Sync rate: 0.051682692307692304
# Overlapping pair:  [46 55]
# Remove 1 violations from times1
# Added 15 spikes to spike train 46 and 17 spikes to spike train 55 Sync rate: 0.04980842911877394
# Overlapping pair:  [47 48]
# Added 24 spikes to spike train 47 and 14 spikes to spike train 48 Sync rate: 0.050514499532273154
# Overlapping pair:  [50 56]
# Remove 1 violations from times1
# Added 16 spikes to spike train 50 and 16 spikes to spike train 56 Sync rate: 0.050731707317073174
# Overlapping pair:  [50 59]
# Added 18 spikes to spike train 50 and 5 spikes to spike train 59 Sync rate: 0.05115712545676005
# Overlapping pair:  [56 59]
# Remove 1 violations from times2
# Added 18 spikes to spike train 56 and 4 spikes to spike train 59 Sync rate: 0.05013550135501355
# Overlapping pair:  [43 57]
# Remove 1 violations from times1
# Added 27 spikes to spike train 43 and 20 spikes to spike train 57 Sync rate: 0.05042016806722689
# Computing spike train SNR
# Adding spiketrain annotations
# Convolution seed:  7218
# Electrode modulaton
# Bursting unit:  0
# Bursting unit:  1
# Bursting unit:  2
# Bursting unit:  3
# Bursting unit:  4
# Bursting unit:  5
# Bursting unit:  6
# Bursting unit:  7
# Bursting unit:  8
# Bursting unit:  9
# Bursting unit:  10
# Bursting unit:  11
# Bursting unit:  12
# Bursting unit:  13
# Bursting unit:  14
# Bursting unit:  15
# Bursting unit:  16
# Bursting unit:  17
# Bursting unit:  18
# Bursting unit:  19
# Bursting unit:  20
# Bursting unit:  21
# Bursting unit:  22
# Bursting unit:  23
# Bursting unit:  24
# Bursting unit:  25
# Bursting unit:  26
# Bursting unit:  27
# Bursting unit:  28
# Bursting unit:  29
# Bursting unit:  30
# Bursting unit:  31
# Bursting unit:  32
# Bursting unit:  33
# Bursting unit:  34
# Bursting unit:  35
# Bursting unit:  36
# Bursting unit:  37
# Bursting unit:  38
# Bursting unit:  39
# Bursting unit:  40
# Bursting unit:  41
# Bursting unit:  42
# Bursting unit:  43
# Bursting unit:  44
# Bursting unit:  45
# Bursting unit:  46
# Bursting unit:  47
# Bursting unit:  48
# Bursting unit:  49
# Bursting unit:  50
# Bursting unit:  51
# Bursting unit:  52
# Bursting unit:  53
# Bursting unit:  54
# Bursting unit:  55
# Bursting unit:  56
# Bursting unit:  57
# Bursting unit:  58
# Bursting unit:  59
# Start convolutions for chunk 0
# Convolution with spike: 0
# Convolution with spike: 1
# Convolution with spike: 2
# Convolution with spike: 3
# Convolution with spike: 4
# Convolution with spike: 5
# Convolution with spike: 6
# Convolution with spike: 7
# Convolution with spike: 8
# Convolution with spike: 9
# Convolution with spike: 10
# Convolution with spike: 11
# Convolution with spike: 12
# Convolution with spike: 13
# Convolution with spike: 14
# Convolution with spike: 15
# Convolution with spike: 16
# Convolution with spike: 17
# Convolution with spike: 18
# Convolution with spike: 19
# Convolution with spike: 20
# Convolution with spike: 21
# Convolution with spike: 22
# Convolution with spike: 23
# Convolution with spike: 24
# Convolution with spike: 25
# Convolution with spike: 26
# Convolution with spike: 27
# Convolution with spike: 28
# Convolution with spike: 29
# Convolution with spike: 30
# Convolution with spike: 31
# Convolution with spike: 32
# Convolution with spike: 33
# Convolution with spike: 34
# Convolution with spike: 35
# Convolution with spike: 36
# Convolution with spike: 37
# Convolution with spike: 38
# Convolution with spike: 39
# Convolution with spike: 40
# Convolution with spike: 41
# Convolution with spike: 42
# Convolution with spike: 43
# Convolution with spike: 44
# Convolution with spike: 45
# Convolution with spike: 46
# Convolution with spike: 47
# Convolution with spike: 48
# Convolution with spike: 49
# Convolution with spike: 50
# Convolution with spike: 51
# Convolution with spike: 52
# Convolution with spike: 53
# Convolution with spike: 54
# Convolution with spike: 55
# Convolution with spike: 56
# Convolution with spike: 57
# Convolution with spike: 58
# Convolution with spike: 59
# Done all convolutions for chunk 0
# Start convolutions for chunk 1
# Convolution with spike: 0
# Convolution with spike: 1
# Convolution with spike: 2
# Convolution with spike: 3
# Convolution with spike: 4
# Convolution with spike: 5
# Convolution with spike: 6
# Convolution with spike: 7
# Convolution with spike: 8
# Convolution with spike: 9
# Convolution with spike: 10
# Convolution with spike: 11
# Convolution with spike: 12
# Convolution with spike: 13
# Convolution with spike: 14
# Convolution with spike: 15
# Convolution with spike: 16
# Convolution with spike: 17
# Convolution with spike: 18
# Convolution with spike: 19
# Convolution with spike: 20
# Convolution with spike: 21
# Convolution with spike: 22
# Convolution with spike: 23
# Convolution with spike: 24
# Convolution with spike: 25
# Convolution with spike: 26
# Convolution with spike: 27
# Convolution with spike: 28
# Convolution with spike: 29
# Convolution with spike: 30
# Convolution with spike: 31
# Convolution with spike: 32
# Convolution with spike: 33
# Convolution with spike: 34
# Convolution with spike: 35
# Convolution with spike: 36
# Convolution with spike: 37
# Convolution with spike: 38
# Convolution with spike: 39
# Convolution with spike: 40
# Convolution with spike: 41
# Convolution with spike: 42
# Convolution with spike: 43
# Convolution with spike: 44
# Convolution with spike: 45
# Convolution with spike: 46
# Convolution with spike: 47
# Convolution with spike: 48
# Convolution with spike: 49
# Convolution with spike: 50
# Convolution with spike: 51
# Convolution with spike: 52
# Convolution with spike: 53
# Convolution with spike: 54
# Convolution with spike: 55
# Convolution with spike: 56
# Convolution with spike: 57
# Convolution with spike: 58
# Convolution with spike: 59
# Done all convolutions for chunk 1
# Adding noise
# Noise seed:  6656
# g:\anaconda3\lib\site-packages\MEArec\generators\recgensteps.py:264: RuntimeWarning: covariance is not positive-semidefinite.
#   additive_noise = noise_level * np.random.multivariate_normal(np.zeros(n_elec), cov_dist,
# g:\anaconda3\lib\site-packages\MEArec\generators\recgensteps.py:271: RuntimeWarning: covariance is not positive-semidefinite.
#   np.random.multivariate_normal(np.zeros(n_elec), cov_dist,
# Extracting spike waveforms
# Elapsed time:  2300.9501077000004
# Impossible to delete temp file: TXadB_mearec_tmp_file_recordings.raw Error [WinError 32] 另一个程序正在使用此文件，进程无法访问。: 'TXadB_mearec_tmp_file_recordings.raw'
# Impossible to delete temp file: TXadB_mearec_tmp_file_spike_traces.raw Error [WinError 32] 另一个程序正在使用此文件，进程无法访问。: 'TXadB_mearec_tmp_file_spike_traces.raw'
# Deleted TXadB_templates_pad.raw
# Impossible to delete temp file: TXadB_templates_resample.raw Error [WinError 2] 系统找不到指定的文件。: 'TXadB_templates_resample.raw'
# Deleted TXadB_templates_jitter.raw
# Deleted TXadB_mearec_tmp_noise_file.raw
